# %%
# To add a new cell, type '# %%'
# To add a new markdown cell, type '# %% [markdown]'
# %%
import iris
import numpy as np
import sys
#sys.path.append('/pf/b/b381639/Analysis')
#import fxtian_function as fx
from iris.time import PartialDateTime
import datetime
import cf_units
import iris.coord_categorisation
import iris.quickplot as qplt
import matplotlib.pyplot as plt
import numpy as np


import xarray as ar



###############
# plot ERA5
###############
datain = iris.load_cube('/scratch/b/b381639/IFS/sst_mean_tco1279-orca025.nc')

#datain.data=datain.data/3600

#datain.data=datain.data*-1
regyonx=datain[0,:,:]

ERA5=regyonx -273.15 #/-86400

print(ERA5)
######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ERA5) # iris cube to xarray
latm=arr.lat.data              # latm is x-axis
lonm=arr.lon.data    #+180         # lonm is y-axis  
#arr = np.roll(arr, 720, axis = 2)
#print(arr[0,0,:].data)
##################
#(2)set color bar and prepare fig size
#levels1=np.arange(-40,2,2) # min and max of the field; dont use it if not sure
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
#cbar='winter'
levels1=np.arange(12,34,1) # min and max of the field; dont use it if not sure
#cbar='ocean'
cbar='Spectral_r'
#cbar='YlGnBu'
plt.figure(figsize=(30,10))

########
#plot the figure
plt.contourf(lonm,latm,arr,levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr,cmap = cbar)
#plt.title('SST- ICON 5N-5S daily from 20/1/2020')

plt.title('SST IFS',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.13)
cbar.ax.tick_params(labelsize = 25)
        

        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
plt.savefig('SST_IFS_tropical.eps',format='eps',dpi=1000)
# Out:
# unknown / (unknown)                 (latitude: 60; longitude: 360)
#     Dimension coordinates:
#         latitude                             x              -
#         longitude                            -              x
#     Scalar coordinates:
#         time                        2021-01-10 00:00:00, bound=(2020-01-21 00:00:00, 2021-12-31 00:00:00)
#     Attributes:
#         CDI                         'Climate Data Interface version 1.9.10 (https://mpimet.mpg.de/cdi)'
#         CDO                         'Climate Data Operators version 1.9.10 (https://mpimet.mpg.de/cdo)'
#         Conventions                 'CF-1.6'
#         history                     'Fri Jul 01 11:39:46 2022: cdo timmean sst_daily_tco1279-orca025_tropical.nc...

# %%
# To add a new cell, type '# %%'
# To add a new markdown cell, type '# %% [markdown]'
# %%
import iris
import numpy as np
import sys
#sys.path.append('/pf/b/b381639/Analysis')
#import fxtian_function as fx
from iris.time import PartialDateTime
import datetime
import cf_units
import iris.coord_categorisation
import iris.quickplot as qplt
import matplotlib.pyplot as plt
import numpy as np


import xarray as ar



###############
# plot ERA5
###############
datain = iris.load_cube('/work/bb1153/b381639/ERA5/SST_tropical.nc')

#datain.data=datain.data/3600

#datain.data=datain.data*-1
regyonx=datain[0,:,:]

ERA5=regyonx -273.15 #/-86400

print(ERA5)
######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ERA5) # iris cube to xarray
latm=arr.latitude.data              # latm is x-axis
lonm=arr.longitude.data    #+180         # lonm is y-axis  
#arr = np.roll(arr, 720, axis = 2)
#print(arr[0,0,:].data)
##################
#(2)set color bar and prepare fig size
#levels1=np.arange(-40,2,2) # min and max of the field; dont use it if not sure
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
#cbar='winter'
levels1=np.arange(12,34,1) # min and max of the field; dont use it if not sure
#cbar='ocean'
cbar='Spectral_r'
#cbar='YlGnBu'
plt.figure(figsize=(30,10))

########
#plot the figure
plt.contourf(lonm,latm,arr,levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr,cmap = cbar)
#plt.title('SST- ICON 5N-5S daily from 20/1/2020')

plt.title('SST ERA5',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.13)
cbar.ax.tick_params(labelsize = 25)
        

        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
plt.savefig('SST_ERA5_tropical.eps',format='eps',dpi=1000)
# Out:
# unknown / (K)                       (latitude: 241; longitude: 1440)
#     Dimension coordinates:
#         latitude                             x               -
#         longitude                            -               x
#     Scalar coordinates:
#         time                        2000-06-16 00:00:00, bound=(1979-01-01 00:00:00, 2021-12-01 00:00:00)
#     Attributes:
#         CDI                         'Climate Data Interface version 1.9.10 (https://mpimet.mpg.de/cdi)'
#         CDO                         'Climate Data Operators version 1.9.10 (https://mpimet.mpg.de/cdo)'
#         Conventions                 'CF-1.6'
#         history                     'Fri Jul 01 11:59:34 2022: cdo sellonlatbox,0,360,-30,30 SST_timmean.nc...

# %%
# To add a new cell, type '# %%'
# To add a new markdown cell, type '# %% [markdown]'
# %%
import iris
import numpy as np
import sys
#sys.path.append('/pf/b/b381639/Analysis')
#import fxtian_function as fx
from iris.time import PartialDateTime
import datetime
import cf_units
import iris.coord_categorisation
import iris.quickplot as qplt
import matplotlib.pyplot as plt
import numpy as np


import xarray as ar



###############
# plot ERA5
###############
datain = iris.load_cube('/work/bb1153/b381639/ERA5/SST.nc')

#datain.data=datain.data/3600

#datain.data=datain.data*-1
regyonx=datain[0,:,:]

ERA5=regyonx -273.15 #/-86400

print(ERA5)
######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ERA5) # iris cube to xarray
latm=arr.latitude.data              # latm is x-axis
lonm=arr.longitude.data    #+180         # lonm is y-axis  
#arr = np.roll(arr, 720, axis = 2)
#print(arr[0,0,:].data)
##################
#(2)set color bar and prepare fig size
#levels1=np.arange(-40,2,2) # min and max of the field; dont use it if not sure
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
#cbar='winter'
levels1=np.arange(2,34,2) # min and max of the field; dont use it if not sure
#cbar='ocean'
cbar='Spectral_r'
#cbar='YlGnBu'
plt.figure(figsize=(30,10))

########
#plot the figure
plt.contourf(lonm,latm,arr,levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr,cmap = cbar)
#plt.title('SST- ICON 5N-5S daily from 20/1/2020')

plt.title('SST ERA5',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.13)
cbar.ax.tick_params(labelsize = 25)
        

        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
plt.savefig('SST_ERA5.eps',format='eps',dpi=1000)
# Out:
# unknown / (K)                       (latitude: 401; longitude: 961)
#     Dimension coordinates:
#         latitude                             x               -
#         longitude                            -               x
#     Scalar coordinates:
#         time                        2000-06-16 00:00:00, bound=(1979-01-01 00:00:00, 2021-12-01 00:00:00)
#     Attributes:
#         CDI                         'Climate Data Interface version 1.9.10 (https://mpimet.mpg.de/cdi)'
#         CDO                         'Climate Data Operators version 1.9.10 (https://mpimet.mpg.de/cdo)'
#         Conventions                 'CF-1.6'
#         history                     'Wed Jun 15 16:10:33 2022: cdo sellonlatbox,30,270,-50,50 SST_timmean.nc...

# %%
# To add a new cell, type '# %%'
# To add a new markdown cell, type '# %% [markdown]'
# %%
import iris
import numpy as np
import sys
#sys.path.append('/pf/b/b381639/Analysis')
#import fxtian_function as fx
from iris.time import PartialDateTime
import datetime
import cf_units
import iris.coord_categorisation
import iris.quickplot as qplt
import matplotlib.pyplot as plt
import numpy as np


import xarray as ar



###############
# plot ERA5
###############
datain = iris.load_cube('/work/bb1153/b381639/NorESM/SST_150.nc')
#datain.data=datain.data/3600

datain.data=datain.data
regyonx=datain[0,:,:]

ERA5=regyonx -273.15 #*-1
print(ERA5)

######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ERA5) # iris cube to xarray
latm=arr.latitude.data              # latm is x-axis
lonm=arr.longitude.data # +180           # lonm is y-axis  

print(latm)
#arr = np.roll(arr, 360, axis = 2)
###################
#(2)set color bar and prepare fig size
levels1=np.arange(2,34,2) # min and max of the field; dont use it if not sure
#levels1=np.arange(-0.1,0.11,0.01)
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
#cbar='winter'
#levels1=np.arange(-5.,5.,0.5) # min and max of the field; dont use it if not sure
#cbar='ocean'
#cbar='seismic'
cbar='Spectral_r'
plt.figure(figsize=(30,10))

########
#plot the figure
plt.contourf(lonm,latm,arr,levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr,cmap = cbar)
#plt.title('SST- ICON 5N-5S daily from 20/1/2020')

plt.title('SST NorESM1.3',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.13)
cbar.ax.tick_params(labelsize = 25)
        

        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
plt.savefig('SST_NorESM.eps',format='eps',dpi=1000)
# Out:
# unknown / (K)                       (latitude: 200; longitude: 480)
#     Dimension coordinates:
#         latitude                             x               -
#         longitude                            -               x
#     Scalar coordinates:
#         time                        0150-06-30 18:00:00, bound=(0150-01-01 00:00:00, 0150-12-31 00:00:00)
#     Attributes:
#         CDI                         'Climate Data Interface version 1.9.10 (https://mpimet.mpg.de/cdi)'
#         CDO                         'Climate Data Operators version 1.9.10 (https://mpimet.mpg.de/cdo)'
#         Conventions                 'CF-1.6'
#         frequency                   'mon'
#         history                     'Wed Jun 15 16:35:26 2022: cdo sellonlatbox,30,270,-50,50 SST_150_timmean.nc...
# [-49.75 -49.25 -48.75 -48.25 -47.75 -47.25 -46.75 -46.25 -45.75 -45.25
#  -44.75 -44.25 -43.75 -43.25 -42.75 -42.25 -41.75 -41.25 -40.75 -40.25
#  -39.75 -39.25 -38.75 -38.25 -37.75 -37.25 -36.75 -36.25 -35.75 -35.25
#  -34.75 -34.25 -33.75 -33.25 -32.75 -32.25 -31.75 -31.25 -30.75 -30.25
#  -29.75 -29.25 -28.75 -28.25 -27.75 -27.25 -26.75 -26.25 -25.75 -25.25
#  -24.75 -24.25 -23.75 -23.25 -22.75 -22.25 -21.75 -21.25 -20.75 -20.25
#  -19.75 -19.25 -18.75 -18.25 -17.75 -17.25 -16.75 -16.25 -15.75 -15.25
#  -14.75 -14.25 -13.75 -13.25 -12.75 -12.25 -11.75 -11.25 -10.75 -10.25
#   -9.75  -9.25  -8.75  -8.25  -7.75  -7.25  -6.75  -6.25  -5.75  -5.25
#   -4.75  -4.25  -3.75  -3.25  -2.75  -2.25  -1.75  -1.25  -0.75  -0.25
#    0.25   0.75   1.25   1.75   2.25   2.75   3.25   3.75   4.25   4.75
#    5.25   5.75   6.25   6.75   7.25   7.75   8.25   8.75   9.25   9.75
#   10.25  10.75  11.25  11.75  12.25  12.75  13.25  13.75  14.25  14.75
#   15.25  15.75  16.25  16.75  17.25  17.75  18.25  18.75  19.25  19.75
#   20.25  20.75  21.25  21.75  22.25  22.75  23.25  23.75  24.25  24.75
#   25.25  25.75  26.25  26.75  27.25  27.75  28.25  28.75  29.25  29.75
#   30.25  30.75  31.25  31.75  32.25  32.75  33.25  33.75  34.25  34.75
#   35.25  35.75  36.25  36.75  37.25  37.75  38.25  38.75  39.25  39.75
#   40.25  40.75  41.25  41.75  42.25  42.75  43.25  43.75  44.25  44.75
#   45.25  45.75  46.25  46.75  47.25  47.75  48.25  48.75  49.25  49.75]

# %%
# To add a new cell, type '# %%'
# To add a new markdown cell, type '# %% [markdown]'
# %%
import iris
import numpy as np
import sys
#sys.path.append('/pf/b/b381639/Analysis')
#import fxtian_function as fx
from iris.time import PartialDateTime
import datetime
import cf_units
import iris.coord_categorisation
import iris.quickplot as qplt
import matplotlib.pyplot as plt
import numpy as np


import xarray as ar



###############
# plot ERA5
###############
datain = iris.load_cube('/work/bb1153/b381639/NorESM2/SST.nc')

#datain.data=datain.data/3600

#datain.data=datain.data*-1
regyonx=datain[0,:,:]

ERA5=regyonx #*-1

print(ERA5)

######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ERA5) # iris cube to xarray
latm=arr.latitude.data              # latm is x-axis
lonm=arr.longitude.data #+180             # lonm is y-axis  
# arr = np.roll(arr, 360, axis = 2)
##################
#(2)set color bar and prepare fig size
levels1=np.arange(2,34,2) # min and max of the field; dont use it if not sure
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
cbar='winter'
#levels1=np.arange(-5.,5.,0.5) # min and max of the field; dont use it if not sure
#cbar='ocean'
#cbar='seismic'
cbar='Spectral_r'
plt.figure(figsize=(30,10))

########
#plot the figure
plt.contourf(lonm,latm,arr,levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr,cmap = cbar)
#plt.title('SST- ICON 5N-5S daily from 20/1/2020')

plt.title('SST NorESM2',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.13)
cbar.ax.tick_params(labelsize = 25)
        

        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
plt.savefig('SST_NorESM2.eps',format='eps',dpi=1000)
# Out:
# /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/fileformats/cf.py:859: UserWarning: Missing CF-netCDF measure variable 'areacello', referenced by netCDF variable 'tos'
#   warnings.warn(
# sea_surface_temperature / (degC)    (-- : 211; -- : 240)
#     Auxiliary coordinates:
#         latitude                        x         x
#         longitude                       x         x
#     Scalar coordinates:
#         time                        2005-01-01 00:00:00, bound=(2000-01-01 00:00:00, 2010-01-01 00:00:00)
#     Cell methods:
#         mean where sea              area
#         mean                        time
#     Attributes:
#         CDI                         'Climate Data Interface version 1.9.10 (https://mpimet.mpg.de/cdi)'
#         CDO                         'Climate Data Operators version 1.9.10 (https://mpimet.mpg.de/cdo)'
#         Conventions                 'CF-1.7 CMIP-6.2'
#         activity_id                 'CMIP'
#         branch_method               'Hybrid-restart from year 1661-01-01 of piControl'
#         branch_time                 0.0
#         branch_time_in_child        0.0
#         branch_time_in_parent       452600.0
#         cdo_openmp_thread_number    36
#         cmor_version                '3.5.0'
#         comment                     'Temperature of upper boundary of the liquid ocean, including temperatures...
#         contact                     'Please send any requests or bug reports to noresm-ncc@met.no.'
#         creation_date               '2019-10-16T07:40:24Z'
#         data_specs_version          '01.00.31'
#         experiment                  'all-forcing simulation of the recent past'
#         experiment_id               'historical'
#         external_variables          'areacello'
#         forcing_index               1
#         frequency                   'year'
#         further_info_url            'https://furtherinfo.es-doc.org/CMIP6.NCC.NorESM2-LM.historical.none.r...
#         grid                        'tripolar grid with 1deg nominal resolution'
#         grid_label                  'gn'
#         history                     "2019-10-16T07:40:24Z altered by CMOR: Converted type from 'd' to 'f'....
#         initialization_index        1
#         institution                 'NorESM Climate modeling Consortium consisting of CICERO (Center for International...
#         institution_id              'NCC'
#         license                     'CMIP6 model data produced by NCC is licensed under a Creative Commons...
#         mip_era                     'CMIP6'
#         model_id                    'NorESM2-LM'
#         nominal_resolution          '100 km'
#         original_name               'sst'
#         parent_activity_id          'CMIP'
#         parent_experiment_id        'piControl'
#         parent_mip_era              'CMIP6'
#         parent_source_id            'NorESM2-LM'
#         parent_sub_experiment_id    'none'
#         parent_time_units           'days since 0421-01-01'
#         parent_variant_label        'r1i1p1f1'
#         physics_index               1
#         product                     'model-output'
#         realization_index           3
#         realm                       'ocean'
#         run_variant                 'N/A'
#         source                      'NorESM2-LM (2017): \naerosol: OsloAero\natmos: CAM-OSLO (2 degree resolution;...
#         source_id                   'NorESM2-LM'
#         source_type                 'AOGCM AER BGC'
#         sub_experiment              'none'
#         sub_experiment_id           'none'
#         table_id                    'Oday'
#         table_info                  'Creation Date:(24 July 2019) MD5:0bb394a356ef9d214d027f1aca45853e'
#         title                       'NorESM2-LM output prepared for CMIP6'
#         tracking_id                 'hdl:21.14100/3d2f533f-8cf1-462c-b4f0-e6155b80ce45'
#         variable_id                 'tos'
#         variant_label               'r3i1p1f1'

# %%
###############
# plot ICON
###############
datain = iris.load_cube('/work/bb1153/b381639/model/data_icon/sfcwind_2d_ml_ocean_mean.nc')

datain.data=datain.data

#datain.data=datain.data*-1
regyonx=datain[:,0,:,:]

ERA5=regyonx

######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ERA5) # iris cube to xarray
latm=arr.latitude.data              # latm is x-axis
lonm=arr.longitude.data +180            # lonm is y-axis  

##################
#(2)set color bar and prepare fig size
levels1=np.arange(0,10,.5) # min and max of the field; dont use it if not sure
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
#cbar='winter'
#levels1=np.arange(-.5,.5,0.05) # min and max of the field; dont use it if not sure
#cbar='ocean'
#cbar='seismic'
cbar='YlGnBu'
arr = np.roll(arr, 720, axis = 2)
plt.figure(figsize=(30,10))

########
#plot the figure
plt.contourf(lonm,latm,arr[0,:,:],levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr[0,:,:],cmap = cbar)
#plt.title('SST- ICON 5N-5S daily from 20/1/2020')

plt.title('surface windspeed ICON',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.13)
cbar.ax.tick_params(labelsize = 25)
        

        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
plt.savefig('surface_wind_ICON.eps',format='eps',dpi=1000)
# Out:
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:2190: UserWarning: Ignoring netCDF variable 'time' invalid units 'day as %Y%m%d.%f'
#   warnings.warn(msg)
