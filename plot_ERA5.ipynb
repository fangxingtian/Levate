# %%
# To add a new cell, type '# %%'
# To add a new markdown cell, type '# %% [markdown]'
# %%
import iris
import numpy as np
import sys
sys.path.append('/pf/b/b381639/Analysis')
import fxtian_function as fx
from iris.time import PartialDateTime
import datetime
import cf_units
import iris.coord_categorisation
import iris.quickplot as qplt
import matplotlib.pyplot as plt
import numpy as np
import xarray as ar

# %%
###############
# plot ERA5
###############
datain = iris.load_cube('/work/bb1153/b381639/ERA5/regress_slhf_sfcwind.nc')

datain.data=datain.data/3600

#datain.data=datain.data*-1
regyonx=datain[:,::4,::4]

ERA5=regyonx

######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(regyonx) # iris cube to xarray
latm=arr.latitude.data              # latm is x-axis
lonm=arr.longitude.data             # lonm is y-axis  

##################
#(2)set color bar and prepare fig size
levels1=np.arange(-40,0,2) # min and max of the field; dont use it if not sure
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
#cbar='winter'
#levels1=np.arange(-0.2,0.2,0.02) # min and max of the field; dont use it if not sure
cbar='ocean'
plt.figure(figsize=(30,10))

########
#plot the figure
plt.contourf(lonm,latm,arr[0,:,:],levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr[0,:,:],cmap = cbar)
#plt.title('SST- ICON 5N-5S daily from 20/1/2020')
plt.colorbar(orientation='horizontal', pad=0.04)

#####save figure
plt.savefig('regress_slhf_on_wind_ERA5.png',dpi=200)

# %%
###############
# plot ERA5
###############
datain = iris.load_cube('/work/bb1153/b381639/ERA5/regress_sst_sfcwind.nc')

datain.data=datain.data

#datain.data=datain.data*-1
regyonx=datain[:,::4,::4]

ERA5=regyonx

######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ERA5) # iris cube to xarray
latm=arr.latitude.data              # latm is x-axis
lonm=arr.longitude.data             # lonm is y-axis  

##################
#(2)set color bar and prepare fig size
#levels1=np.arange(-40,0,2) # min and max of the field; dont use it if not sure
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
#cbar='winter'
levels1=np.arange(-.25,.25,0.05) # min and max of the field; dont use it if not sure
#cbar='ocean'
#cbar='seismic'
cbar='jet'
plt.figure(figsize=(30,10))

########
#plot the figure
plt.contourf(lonm,latm,arr[0,:,:],levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr[0,:,:],cmap = cbar)
#plt.title('SST- ICON 5N-5S daily from 20/1/2020')

plt.title('regress sst onto windspeed ERA5',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.1)
cbar.ax.tick_params(labelsize = 17)
        
plt.xlabel('longitude')#, fontsize=28)
plt.ylabel('latitude')#, fontsize=26)
plt.xticks(fontsize=20)#, rotation=90)
plt.yticks(fontsize=20)#, rotation=90)


#####save figure
plt.savefig('regress_sst_on_wind_ERA5.png',dpi=200)

# %%
###############
# plot icon
###############
datain = iris.load_cube('/work/bb1153/b381639/model/data_icon/regress_sst_sfcwind.nc')
regyonx=datain #[:,::4,::4]
icon=regyonx
######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(icon) # iris cube to xarray
latm=arr.latitude.data              # latm is x-axis
lonm=arr.longitude.data             # lonm is y-axis  

##################
#(2)set color bar and prepare fig size
#levels1=np.arange(-40,0,2) # min and max of the field; dont use it if not sure
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
#cbar='winter'
levels1=np.arange(-.25,.25,0.05) # min and max of the field; dont use it if not sure
#cbar='ocean'
#cbar='seismic'
cbar='jet'
plt.figure(figsize=(30,10))
plt.rcParams['axes.labelsize'] = 25

########
#plot the figure
plt.contourf(lonm,latm,arr[0,:,:],levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr[0,:,:],cmap = cbar)
#plt.title('SST- ICON 5N-5S daily from 20/1/2020')
plt.title('regress sst onto windspeed ICON',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.1)
cbar.ax.tick_params(labelsize = 17)
        
plt.xlabel('longitude')#, fontsize=28)
plt.ylabel('latitude')#, fontsize=26)
plt.xticks(fontsize=20)#, rotation=90)
plt.yticks(fontsize=20)#, rotation=90)

#####save figure
plt.savefig('regress_sst_on_wind_icon.png',dpi=200)

# %%
D=icon-ERA5

######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(D) # iris cube to xarray
latm=arr.latitude.data              # latm is x-axis
lonm=arr.longitude.data             # lonm is y-axis  

##################
#(2)set color bar and prepare fig size
#levels1=np.arange(-40,0,2) # min and max of the field; dont use it if not sure
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
#cbar='winter'
levels1=np.arange(-.25,.25,0.05) # min and max of the field; dont use it if not sure
#cbar='ocean'
#cbar='seismic'
cbar='jet'
plt.figure(figsize=(30,10))
plt.rcParams['axes.labelsize'] = 25

########
#plot the figure
plt.contourf(lonm,latm,arr[0,:,:],levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr[0,:,:],cmap = cbar)
plt.title('regress sst onto windspeed ICON-ERA5',fontsize=30)


cbar=plt.colorbar(orientation='horizontal', pad=0.1)
cbar.ax.tick_params(labelsize = 17)
        
plt.xlabel('longitude')#, fontsize=28)
plt.ylabel('latitude')#, fontsize=26)
plt.xticks(fontsize=20)#, rotation=90)
plt.yticks(fontsize=20)#, rotation=90)
#####save figure
plt.savefig('regress_sst_on_wind_icon-ERA5.png',dpi=200)

# %%
###############
# plot model
###############
datain = iris.load_cube('/work/bb1153/b381639/model/data_icon/regress_hfls_sfcwind.nc')

#datain.data=datain.data/3600

#datain.data=datain.data*-1
regyonx=datain

icon=regyonx

######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(datain) # iris cube to xarray
latm=arr.latitude.data              # latm is x-axis
lonm=arr.longitude.data             # lonm is y-axis  

##################
#(2)set color bar and prepare fig size
levels1=np.arange(-40,0,2) # min and max of the field; dont use it if not sure
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
#cbar='winter'
#levels1=np.arange(-0.2,0.2,0.02) # min and max of the field; dont use it if not sure
cbar='ocean'
plt.figure(figsize=(30,10))

########
#plot the figure
plt.contourf(lonm,latm,arr[0,:,:],levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr[0,:,:],cmap = cbar)
#plt.title('SST- ICON 5N-5S daily from 20/1/2020')
plt.colorbar(orientation='horizontal', pad=0.04)

#####save figure
plt.savefig('regress_slhf_on_wind_icon.png',dpi=200)

# %%
D=icon-ERA5

#datain.data=datain.data*-1
regyonx=D


######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(regyonx) # iris cube to xarray
latm=arr.latitude.data              # latm is x-axis
lonm=arr.longitude.data             # lonm is y-axis  

##################
#(2)set color bar and prepare fig size
levels1=np.arange(-30,30,3) # min and max of the field; dont use it if not sure
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
#cbar='winter'
#levels1=np.arange(-0.2,0.2,0.02) # min and max of the field; dont use it if not sure
#cbar='ocean'
#cbar='seismic'

plt.figure(figsize=(30,10))

########
#plot the figure
plt.contourf(lonm,latm,arr[0,:,:],levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr[0,:,:],cmap = cbar)
#plt.title('SST- ICON 5N-5S daily from 20/1/2020')
plt.colorbar(orientation='horizontal', pad=0.04)

#####save figure
plt.savefig('regress_slhf_on_wind_icon-era5.png',dpi=200)

# %%
###############
# plot ERA5 remove mean
###############
datain = iris.load_cube('/work/bb1153/b381639/ERA5/regress_slhf_sfcwind.nc')

datain.data=datain.data/3600

#datain.data=datain.data*-1
ERA5=datain[:,::4,::4]



rmERA5 = ERA5-ERA5.collapsed(('longitude','latitude'), iris.analysis.MEAN)
regyonx=rmERA5

######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(regyonx) # iris cube to xarray
latm=arr.latitude.data              # latm is x-axis
lonm=arr.longitude.data             # lonm is y-axis  

##################
#(2)set color bar and prepare fig size
levels1=np.arange(-30,30,3) # min and max of the field; dont use it if not sure
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
#cbar='winter'
#levels1=np.arange(-0.2,0.2,0.02) # min and max of the field; dont use it if not sure
#cbar='ocean'
cbar='seismic'
plt.figure(figsize=(30,10))

########
#plot the figure
plt.contourf(lonm,latm,arr[0,:,:],levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr[0,:,:],cmap = cbar)
#plt.title('SST- ICON 5N-5S daily from 20/1/2020')
plt.colorbar(orientation='horizontal', pad=0.04)

#####save figure
plt.savefig('regress_slhf_on_wind_era5_removemean.png',dpi=200)
# Out:
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/iris/cube.py:3218: UserWarning: Collapsing spatial coordinate 'latitude' without weighting
#   warnings.warn(msg.format(coord.name()))
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/iris/coords.py:1410: UserWarning: Collapsing a non-contiguous coordinate. Metadata may not be fully descriptive for 'latitude'.
#   warnings.warn(msg.format(self.name()))
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/iris/coords.py:1410: UserWarning: Collapsing a non-contiguous coordinate. Metadata may not be fully descriptive for 'longitude'.
#   warnings.warn(msg.format(self.name()))

# %%
###############
# plot icon remove mean
###############
datain = iris.load_cube('/work/bb1153/b381639/model/data_icon/regress_hfls_sfcwind.nc')

#datain.data=datain.data/3600

#datain.data=datain.data*-1
regyonx=datain

icon=regyonx



rmicon = icon-np.nanmean(icon.data) #icon.collapsed(('longitude','latitude'), iris.analysis.MEAN)
regyonx=rmicon

######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(regyonx) # iris cube to xarray
latm=arr.latitude.data              # latm is x-axis
lonm=arr.longitude.data             # lonm is y-axis  

##################
#(2)set color bar and prepare fig size
levels1=np.arange(-30,30,3) # min and max of the field; dont use it if not sure
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
#cbar='winter'
#levels1=np.arange(-0.2,0.2,0.02) # min and max of the field; dont use it if not sure
#cbar='ocean'
cbar='seismic'
plt.figure(figsize=(30,10))

########
#plot the figure
plt.contourf(lonm,latm,arr[0,:,:],levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr[0,:,:],cmap = cbar)
#plt.title('SST- ICON 5N-5S daily from 20/1/2020')
plt.colorbar(orientation='horizontal', pad=0.04)

#####save figure
plt.savefig('regress_slhf_on_wind_icon_removemean.png',dpi=200)
