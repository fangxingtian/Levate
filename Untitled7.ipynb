# %%
# import intake
import xarray as xr
import numpy as np
import matplotlib.pylab as plt
import matplotlib.cm as cm
import cmocean.cm as cmo
from scipy.interpolate import CloughTocher2DInterpolator, LinearNDInterpolator, NearestNDInterpolator
import gribscan
import intake
import numcodecs
import dask
import cartopy.crs as ccrs


cat = intake.open_catalog("/home/b/b381639/nextGems_Cycle2/catalog.yaml")
#run = cat.IFS["tco2559-ng5"]
run = cat.IFS["tco1279-orca025"]
data = run.ICMGG_atm2d.to_dask()

# %%
#But fluxes are accumulated from start of the month, or for Jan 2020, it would be Jan 20th. 
#So we need to take the difference from day after to current day. 

yyyys=2020
yyyye=2021
yr=yyyys
#day=4
mms=1
mme=12
cdatearr=[]
dayarr=[]

while yr<=yyyye:
    yyyy=str(yr)
    mth=mms
    if yr==yyyye:
        mthe=mme
    else:
        mthe=12
    while mth<=mthe:
        if mth<10:
            mm='0'+str(mth)
        else:
            mm=str(mth)
        if mth==1 or mth==3 or mth==5 or mth==7 or mth==8 or mth==10 or mth==12:
            daye=31
        elif mth==4 or mth==6 or mth==9 or mth==11:
            daye=30
        if (yr%4)==0 and mth==2:
            daye=29
        elif (yr%4)!=0 and mth==2:
            daye=28
        if yr==2020 and mth==1:
            days=20
        else:
            days=1
        day=days
        tidx=0
        while day<=daye:
            if day<10:
                dd='0'+str(day)
            else:
                dd=str(day)
            cdatearr.append(yyyy+'-'+mm+'-'+dd)
            dayarr.append(day)
            #print(data.str.sel(time=yyyy+'-'+mm+'-'+dd+'T00:00:00.000000000').time)
            day=day+1
            #cidx=cidx+1
        mth=mth+1
    yr=yr+1

print(np.shape(cdatearr)[0]-1)
#print(cdatearr)
# Out:
# 711

# %%
SHFarray=[]
cidx=0
while cidx<=np.shape(cdatearr)[0]-2:
    cdate=cdatearr[cidx]
    cdatep=cdatearr[cidx+1]
    #print(dayarr[cidx+1])
    #dlen=len(dayarr[cidx+1])
    if dayarr[cidx+1]==2 or cidx==0:
        #print('Use only '+cdatep)
        #print('datestamp='+cdate+'T00:00:00.000000000')
        SHFarray.append(data.sshf.sel(time=cdatep+'T00:00:00.000000000').reset_coords('time', drop=True) /86400)
        #print(SHF.max())
    else:
        #print('Use '+cdatep+' - '+cdate)
        SHFarray.append((data.sshf.sel(time=cdatep+'T00:00:00.000000000')-data.str.sel(time=cdate+'T00:00:00.000000000') )/86400)    
        #SHFarray.append(SHF)
    cidx=cidx+1

# %%
xarraySHF
# Out:
# <xarray.DataArray 'sshf' (tim: 711, time: 711, value: 6599680)>
# dask.array<broadcast_to, shape=(711, 711, 6599680), dtype=float64, chunksize=(711, 1, 6599680), chunktype=numpy.ndarray>
# Coordinates:
#   * tim      (tim) datetime64[ns] 2020-01-20 2020-01-21 ... 2021-12-30
#     lat      (value) float64 dask.array<chunksize=(6599680,), meta=np.ndarray>
#     lon      (value) float64 dask.array<chunksize=(6599680,), meta=np.ndarray>
# Dimensions without coordinates: time, value

# %%
#xarraySHF=xr.concat(SHFarray,dim='time')

# %%
import pandas as pd
times = pd.date_range("2020/01/20",periods=711,freq='D',closed='left')
time_da = xr.DataArray(times, [('time', times)])
# Out:
# /tmp/ipykernel_45425/3532847830.py:2: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   times = pd.date_range("2020/01/20",periods=711,freq='D',closed='left')

# %%
time_da
# Out:
# <xarray.DataArray (time: 711)>
# array(['2020-01-20T00:00:00.000000000', '2020-01-21T00:00:00.000000000',
#        '2020-01-22T00:00:00.000000000', ..., '2021-12-28T00:00:00.000000000',
#        '2021-12-29T00:00:00.000000000', '2021-12-30T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 2020-01-20 2020-01-21 ... 2021-12-30

# %%
xarraySHF=xarraySHF.expand_dims(time=time_da)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [37], in <cell line: 1>()
# ----> 1 xarraySHF=xarraySHF.expand_dims(time=time_da)
#
# File /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/xarray/core/dataarray.py:1957, in DataArray.expand_dims(self, dim, axis, **dim_kwargs)
#    1954     dim = {cast(Hashable, dim): 1}
#    1956 dim = either_dict_or_kwargs(dim, dim_kwargs, "expand_dims")
# -> 1957 ds = self._to_temp_dataset().expand_dims(dim, axis)
#    1958 return self._from_temp_dataset(ds)
#
# File /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/xarray/core/dataset.py:3661, in Dataset.expand_dims(self, dim, axis, **dim_kwargs)
#    3659 for d in dim:
#    3660     if d in self.dims:
# -> 3661         raise ValueError(f"Dimension {d} already exists.")
#    3662     if d in self._variables and not utils.is_scalar(self._variables[d]):
#    3663         raise ValueError(
#    3664             "{dim} already exists as coordinate or"
#    3665             " variable name.".format(dim=d)
#    3666         )
#
# ValueError: Dimension time already exists.

# %%
xarraySHF.time
# Out:
# <xarray.DataArray 'time' (time: 711)>
# array([  0,   1,   2, ..., 708, 709, 710])
# Dimensions without coordinates: time

# %%
xarraySHF.to_netcdf('/scratch/b/b381639/IFS/SSHF_daily_tco1279-orca025.nc')
