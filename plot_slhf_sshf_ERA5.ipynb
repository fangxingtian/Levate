# %%
# To add a new cell, type '# %%'
# To add a new markdown cell, type '# %% [markdown]'
# %%
import iris
import numpy as np
import sys
sys.path.append('/pf/b/b381639/Analysis')
import fxtian_function as fx
from iris.time import PartialDateTime
import datetime
import cf_units
import iris.coord_categorisation
import iris.quickplot as qplt
import matplotlib.pyplot as plt
import numpy as np
import xarray as ar

# %%
###############
# plot ERA5
###############
datain = iris.load_cube('/scratch/b/b381639/IFS/regress_sst2wsp10_IFS_ocean.nc')
#datain.data=datain.data*-1
regyonx=datain#[:,::4,::4]
ICON=regyonx

######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ICON) # iris cube to xarray
latm=arr.lat.data              # latm is x-axis
lonm=arr.lon.data 
##################
#(2)set color bar and prepare fig size
#levels1=np.arange(-10.,10.,1.) # min and max of the field; dont use it if not sure
levels1=np.linspace(-0.55,0.55,23)
#cbar='ocean'
cbar='bwr'
#cbar='jet'

plt.figure(figsize=(30,10))
#plot the figure
plt.contourf(lonm,latm,arr[0,:,:],levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr[0,:,:],cmap = cbar)
plt.title('regress sst to wind IFS daily',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.12)
cbar.ax.tick_params(labelsize = 17)
        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
plt.savefig('regress_sst_sfcwind_IFS_daily.eps',format='eps',dpi=1000)

# %%
###############
# plot ERA5
###############
datain = iris.load_cube('/scratch/b/b381639/IFS/regress_slhf2wsp10_IFS_ocean.nc')
#datain.data=datain.data*-1
regyonx=datain*-1 #/-3600#[:,::4,::4]
ICON=regyonx

######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ICON) # iris cube to xarray
latm=arr.lat.data              # latm is x-axis
lonm=arr.lon.data 
##################
#(2)set color bar and prepare fig size
#levels1=np.arange(-10.,10.,1.) # min and max of the field; dont use it if not sure
levels1=np.linspace(-44,44,23)
#cbar='ocean'
cbar='bwr'
#cbar='jet'

plt.figure(figsize=(30,10))
#plot the figure
plt.contourf(lonm,latm,arr[0,:,:],levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr[0,:,:],cmap = cbar)
plt.title('regress slhf to wind IFS daily',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.12)
cbar.ax.tick_params(labelsize = 17)
        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
plt.savefig('regress_slhf_sfcwind_IFS_daily.eps',format='eps',dpi=1000)

# %%
###############
# plot ERA5
###############
datain = iris.load_cube('/scratch/b/b381639/IFS/regress_sshf2wsp10_IFS_ocean.nc')
#datain.data=datain.data*-1
regyonx=datain*-1 #/-3600#[:,::4,::4]
ICON=regyonx

######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ICON) # iris cube to xarray
latm=arr.lat.data              # latm is x-axis
lonm=arr.lon.data 
##################
#(2)set color bar and prepare fig size
#levels1=np.arange(-10.,10.,1.) # min and max of the field; dont use it if not sure
levels1=np.linspace(-5.5,5.5,23)
#cbar='ocean'
cbar='bwr'
#cbar='jet'

plt.figure(figsize=(30,10))
#plot the figure
plt.contourf(lonm,latm,arr[0,:,:],levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr[0,:,:],cmap = cbar)
plt.title('regress sshf to wind IFS daily',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.12)
cbar.ax.tick_params(labelsize = 17)
        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
plt.savefig('regress_sshf_sfcwind_IFS_daily.eps',format='eps',dpi=1000)

# %%
###############
# plot ERA5
###############
datain = iris.load_cube('/scratch/b/b381639/IFS/regress_slhf2sshf_IFS_ocean.nc')
#datain.data=datain.data*-1
regyonx=datain#[:,::4,::4]
ICON=regyonx

######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ICON) # iris cube to xarray
latm=arr.lat.data              # latm is x-axis
lonm=arr.lon.data 
##################
#(2)set color bar and prepare fig size
#levels1=np.arange(-10.,10.,1.) # min and max of the field; dont use it if not sure
levels1=np.linspace(-11.,11.,23)
#cbar='ocean'
cbar='bwr'
#cbar='jet'

plt.figure(figsize=(30,10))
#plot the figure
plt.contourf(lonm,latm,arr[0,:,:],levels=levels1,cmap = cbar)
plt.title('regress slhf to sshf IFS daily',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.12)
cbar.ax.tick_params(labelsize = 17)
        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
plt.savefig('regress_slhf_sshf_IFS_daily.eps',format='eps',dpi=1000)

# %%
###############
# plot ERA5
###############
datain = iris.load_cube('/work/bb1153/b381639/ERA5/regress_slhf_sshf.nc')
#datain.data=datain.data*-1
regyonx=datain#[:,::4,::4]
ICON=regyonx

######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ICON) # iris cube to xarray
latm=arr.latitude.data              # latm is x-axis
lonm=arr.longitude.data 
##################
#(2)set color bar and prepare fig size
#levels1=np.arange(-10.,10.,1.) # min and max of the field; dont use it if not sure
levels1=np.linspace(-11.,11.,23)
#cbar='ocean'
cbar='bwr'
#cbar='jet'

plt.figure(figsize=(30,10))
#plot the figure
plt.contourf(lonm,latm,arr[0,:,:],levels=levels1,cmap = cbar)
plt.title('regress slhf to sshf ERA5 daily',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.12)
cbar.ax.tick_params(labelsize = 17)
        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
plt.savefig('regress_slhf_sshf_ERA5_daily.eps',format='eps',dpi=1000)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [4], in <cell line: 4>()
#       1 ###############
#       2 # plot ERA5
#       3 ###############
# ----> 4 datain = iris.load_cube('/work/bb1153/b381639/ERA5/regress_slhf_sshf.nc')
#       5 #datain.data=datain.data*-1
#       6 regyonx=datain#[:,::4,::4]
#
# File /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/__init__.py:340, in load_cube(uris, constraint, callback)
#     337 if len(constraints) != 1:
#     338     raise ValueError("only a single constraint is allowed")
# --> 340 cubes = _load_collection(uris, constraints, callback).cubes()
#     342 try:
#     343     cube = cubes.merge_cube()
#
# File /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/__init__.py:275, in _load_collection(uris, constraints, callback)
#     273 try:
#     274     cubes = _generate_cubes(uris, callback, constraints)
# --> 275     result = _CubeFilterCollection.from_cubes(cubes, constraints)
#     276 except EOFError as e:
#     277     raise iris.exceptions.TranslationError(
#     278         "The file appears empty or incomplete: {!r}".format(str(e))
#     279     )
#
# File /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/cube.py:104, in _CubeFilterCollection.from_cubes(cubes, constraints)
#     102 pairs = [_CubeFilter(constraint) for constraint in constraints]
#     103 collection = _CubeFilterCollection(pairs)
# --> 104 for cube in cubes:
#     105     collection.add_cube(cube)
#     106 return collection
#
# File /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/__init__.py:260, in _generate_cubes(uris, callback, constraints)
#     258 if scheme == "file":
#     259     part_names = [x[1] for x in groups]
# --> 260     for cube in iris.io.load_files(part_names, callback, constraints):
#     261         yield cube
#     262 elif scheme in ["http", "https"]:
#
# File /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/io/__init__.py:193, in load_files(filenames, callback, constraints)
#     180 """
#     181 Takes a list of filenames which may also be globs, and optionally a
#     182 constraint set and a callback function, and returns a
#    (...)
#     189
#     190 """
#     191 from iris.fileformats import FORMAT_AGENT
# --> 193 all_file_paths = expand_filespecs(filenames)
#     195 # Create default dict mapping iris format handler to its associated filenames
#     196 handler_map = collections.defaultdict(list)
#
# File /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/io/__init__.py:174, in expand_filespecs(file_specs)
#     172         else:
#     173             msg += '\n    * "{}" didn\'t match any files'.format(pattern)
# --> 174     raise IOError(msg)
#     176 return [fname for fnames in all_expanded for fname in fnames]
#
# OSError: One or more of the files specified did not exist:
#     * "/work/bb1153/b381639/ERA5/regress_slhf_sshf.nc" didn't match any files

# %%
###############
# plot ERA5
###############
datain = iris.load_cube('/work/bb1153/b381639/ERA5/regress_sshf_sfcwind.nc')
#datain.data=datain.data*-1
regyonx=datain/-3600#[:,::4,::4]
ICON=regyonx

######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ICON) # iris cube to xarray
latm=arr.latitude.data              # latm is x-axis
lonm=arr.longitude.data 
##################
#(2)set color bar and prepare fig size
#levels1=np.arange(-10.,10.,1.) # min and max of the field; dont use it if not sure
levels1=np.linspace(-5.5,5.5,23)
#cbar='ocean'
cbar='bwr'
#cbar='jet'

plt.figure(figsize=(30,10))
#plot the figure
plt.contourf(lonm,latm,arr[0,:,:],levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr[0,:,:],cmap = cbar)
plt.title('regress sshf to wind ERA5 daily',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.12)
cbar.ax.tick_params(labelsize = 17)
        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
plt.savefig('regress_sshf_sfcwind_ERA5_daily.eps',format='eps',dpi=1000)

# %%
###############
# plot ERA5
###############
datain = iris.load_cube('/work/bb1153/b381639/ERA5/regress_slhf_sfcwind.nc')
#datain.data=datain.data*-1
regyonx=datain/-3600#[:,::4,::4]
ICON=regyonx

######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ICON) # iris cube to xarray
latm=arr.latitude.data              # latm is x-axis
lonm=arr.longitude.data 
##################
#(2)set color bar and prepare fig size
#levels1=np.arange(-10.,10.,1.) # min and max of the field; dont use it if not sure
levels1=np.linspace(-44,44,23)
#cbar='ocean'
cbar='bwr'
#cbar='jet'

plt.figure(figsize=(30,10))
#plot the figure
plt.contourf(lonm,latm,arr[0,:,:],levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr[0,:,:],cmap = cbar)
plt.title('regress slhf to wind ERA5 daily',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.12)
cbar.ax.tick_params(labelsize = 17)
        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
plt.savefig('regress_slhf_sfcwind_ERA5_daily.eps',format='eps',dpi=1000)

# %%
###############
# plot ERA5
###############
datain = iris.load_cube('/work/bb1153/b381639/ERA5/regress_sst_sfcwind.nc')
#datain.data=datain.data*-1
regyonx=datain#[:,::4,::4]
ICON=regyonx

######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ICON) # iris cube to xarray
latm=arr.latitude.data              # latm is x-axis
lonm=arr.longitude.data 
##################
#(2)set color bar and prepare fig size
#levels1=np.arange(-10.,10.,1.) # min and max of the field; dont use it if not sure
levels1=np.linspace(-0.55,0.55,23)
#cbar='ocean'
cbar='bwr'
#cbar='jet'

plt.figure(figsize=(30,10))
#plot the figure
plt.contourf(lonm,latm,arr[0,:,:],levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr[0,:,:],cmap = cbar)
plt.title('regress sst to wind ERA5 daily',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.12)
cbar.ax.tick_params(labelsize = 17)
        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
plt.savefig('regress_sst_sfcwind_ERA5_daily.eps',format='eps',dpi=1000)
