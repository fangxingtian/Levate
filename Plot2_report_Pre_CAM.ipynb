# %%
# To add a new cell, type '# %%'
# To add a new markdown cell, type '# %% [markdown]'
# %%
import iris
import numpy as np
import sys
sys.path.append('/pf/b/b381639/Analysis')
import fxtian_function as fx
from iris.time import PartialDateTime
import datetime
import cf_units
import iris.coord_categorisation
import iris.quickplot as qplt
import matplotlib.pyplot as plt
import numpy as np
import xarray as ar

# %%
###############
# H resolu CAM
###############
datain = iris.load_cube('/work/bb1153/b381639/NorESM/betzy_Hcam5_1.cam.h1.0010-01-01-00000_timmean.nc','PRECT')
datama = iris.load_cube('/work/bb1153/b381639/NorESM/OCNFRAC.nc','OCNFRAC')
#datain.data=datain.data*-1
cubein=datain[0,:,:]*86400000
cubema=datama[0,:,:]

######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(cubein) # iris cube to xarray
arrma=ar.DataArray.from_iris(cubema)
latm=arr.lat.data              # latm is x-axis
lonm=arr.lon.data #+180             # lonm is y-axis  
print(arr[0,:].data)
# Call the cdutil function to generate a mask, 0 for ocean, 1 for land.
# Out:
# dask.array<getitem, shape=(1152,), dtype=float32, chunksize=(1152,), chunktype=numpy.ndarray>
# /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/fileformats/_nc_load_rules/helpers.py:645: UserWarning: Ignoring netCDF variable 'OCNFRAC' invalid units 'fraction'
#   warnings.warn(msg)

# %%
arr.data=arr.where(arrma>0)

lon_min = 0
lon_max = 360
lat_min = -20
lat_max = 20

desired_lon = slice(lon_min, lon_max)
desired_lat = slice(lat_min, lat_max)

# make standard dataset selection
arr_sel_ds = arr.sel(lat=desired_lat, lon=desired_lon)

levels1=np.arange(0.,18.,1.) # min and max of the field; dont use it if not sure
cbar='YlGnBu'
plt.figure(figsize=(30,10))
plt.contourf(arr_sel_ds.lon,arr_sel_ds.lat,arr_sel_ds,levels=levels1,cmap = cbar)
#plt.contourf(arr_sel_ds.lon,arr_sel_ds.lat,arr_sel_ds)

plt.title('Precipitation HR CAM5',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.13)
cbar.ax.tick_params(labelsize = 25)
               
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
plt.savefig('Precipitation_HR_CAM5.eps',format='eps',dpi=1000)

# %%
# To add a new cell, type '# %%'
# To add a new markdown cell, type '# %% [markdown]'
# %%
import iris
import numpy as np
import sys
sys.path.append('/pf/b/b381639/Analysis')
import fxtian_function as fx
from iris.time import PartialDateTime
import datetime
import cf_units
import iris.coord_categorisation
import iris.quickplot as qplt
import matplotlib.pyplot as plt
import numpy as np
import xarray as ar

###############
# H resolu CAM
###############
datain = iris.load_cube('/work/bb1153/b381639/NorESM/betzy_Lcam6_1.cam.h1.0010-01-01-00000_timmean.nc','PRECT')
datama= iris.load_cube('/work/bb1153/b381639/NorESM/betzy_Lcam6_1.cam.h1.0010-01-01-00000_timmean.nc','SST')
#datain.data=datain.data*-1
regyonx=datain[0,:,:]*86400000
ma=datama[0,:,:]
ERA5=regyonx
######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ERA5) # iris cube to xarray
latm=arr.lat.data              # latm is x-axis
lonm=arr.lon.data #+180             # lonm is y-axis  
print(arr[0,:].data)
arrma=ar.DataArray.from_iris(ma)

#arr=np.ma.array(arr,arrma)
arr.data=arr.where(arrma>0)

lon_min = 0
lon_max = 360
lat_min = -20
lat_max = 20

desired_lon = slice(lon_min, lon_max)
desired_lat = slice(lat_min, lat_max)

# make standard dataset selection
arr_sel_ds = arr.sel(lat=desired_lat, lon=desired_lon)

levels1=np.arange(0.,18.,1.) # min and max of the field; dont use it if not sure
cbar='YlGnBu'
plt.figure(figsize=(30,10))
plt.contourf(arr_sel_ds.lon,arr_sel_ds.lat,arr_sel_ds,levels=levels1,cmap = cbar)

plt.title('Precipitation LR CAM6',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.13)
cbar.ax.tick_params(labelsize = 25)
               
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
plt.savefig('Precipitation_LR_CAM6.eps',format='eps',dpi=1000)
# Out:
# dask.array<getitem, shape=(288,), dtype=float32, chunksize=(288,), chunktype=numpy.ndarray>

# %%
# To add a new cell, type '# %%'
# To add a new markdown cell, type '# %% [markdown]'
# %%
import iris
import numpy as np
import sys
sys.path.append('/pf/b/b381639/Analysis')
import fxtian_function as fx
from iris.time import PartialDateTime
import datetime
import cf_units
import iris.coord_categorisation
import iris.quickplot as qplt
import matplotlib.pyplot as plt
import numpy as np


import xarray as ar



###############
# plot ERA5
###############
datain = iris.load_cube('/work/bb1153/b381639/model/NorESM/PRECT_126-150_ocean_trop.nc')
datain.data=datain.data*8.64e7

datain.data=datain.data
regyonx=datain[:,:,:]

ERA5=regyonx

######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ERA5) # iris cube to xarray
latm=arr.latitude.data              # latm is x-axis
lonm=arr.longitude.data +180            # lonm is y-axis  
arr = np.roll(arr, 360, axis = 2)
###################
#(2)set color bar and prepare fig size
levels1=np.arange(0,18,1.) # min and max of the field; dont use it if not sure
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
#cbar='winter'
#levels1=np.arange(-5.,5.,0.5) # min and max of the field; dont use it if not sure
#cbar='ocean'
#cbar='seismic'
cbar='YlGnBu'
plt.figure(figsize=(30,10))

########
#plot the figure
plt.contourf(lonm,latm,arr[0,:,:],levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr[0,:,:],cmap = cbar)
#plt.title('SST- ICON 5N-5S daily from 20/1/2020')

plt.title('Precipitation NorESM1.3',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.13)
cbar.ax.tick_params(labelsize = 25)
        

        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
plt.savefig('Precipitation_NorESM.eps',format='eps',dpi=1000)

# %%
# To add a new cell, type '# %%'
# To add a new markdown cell, type '# %% [markdown]'
# %%
import iris
import numpy as np
import sys
sys.path.append('/pf/b/b381639/Analysis')
import fxtian_function as fx
from iris.time import PartialDateTime
import datetime
import cf_units
import iris.coord_categorisation
import iris.quickplot as qplt
import matplotlib.pyplot as plt
import numpy as np
import xarray as ar



###############
# plot ERA5
###############
datain = iris.load_cube('/work/bb1153/b381639/model/NorESM2/pr_day_NorESM2-LM_historical_r3i1p1f1_glo_2000-9_ocean_trop.nc')

datain.data=datain.data*86400 

#datain.data=datain.data*-1
regyonx=datain[:,:,:]

ERA5=regyonx

######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ERA5) # iris cube to xarray
latm=arr.lat.data              # latm is x-axis
lonm=arr.lon.data #+180             # lonm is y-axis  
#arr = np.roll(arr, 360, axis = 2)
#################
#(2)set color bar and prepare fig size
levels1=np.arange(0,18,1.) # min and max of the field; dont use it if not sure
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
#cbar='winter'
#levels1=np.arange(-5.,5.,0.5) # min and max of the field; dont use it if not sure
#cbar='ocean'
#cbar='seismic'
#cbar='jet'
cbar='YlGnBu'
plt.figure(figsize=(30,10))

########
#plot the figure
plt.contourf(lonm,latm,arr[0,:,:],levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr[0,:,:],cmap = cbar)
#plt.title('SST- ICON 5N-5S daily from 20/1/2020')

plt.title('Precipitation NorESM2',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.13)
cbar.ax.tick_params(labelsize = 25)
        

        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
plt.savefig('Precipitation_NorESM2.eps',format='eps',dpi=1000)
# Out:
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/iris/fileformats/cf.py:803: UserWarning: Missing CF-netCDF measure variable 'areacella', referenced by netCDF variable 'pr'
#   warnings.warn(message % (variable_name, nc_var_name))

# %%
###############
# plot ICON
###############
datain = iris.load_cube('/work/bb1153/b381639/model/data_icon/Prec_2020_tropical_ocean_mean_mmday.nc')

datain.data=datain.data

#datain.data=datain.data*-1
regyonx=datain[:,:,:]

ERA5=regyonx

######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ERA5) # iris cube to xarray
latm=arr.latitude.data              # latm is x-axis
lonm=arr.longitude.data    +180         # lonm is y-axis  
arr = np.roll(arr, 720, axis = 2)
##################
#(2)set color bar and prepare fig size
levels1=np.arange(0,18,1.) # min and max of the field; dont use it if not sure
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
#cbar='winter'
#levels1=np.arange(-.5,.5,0.05) # min and max of the field; dont use it if not sure
#cbar='ocean'
#cbar='seismic'
#cbar='jet'
cbar='YlGnBu'
plt.figure(figsize=(30,10))

########
#plot the figure
plt.contourf(lonm,latm,arr[0,:,:],levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr[0,:,:],cmap = cbar)
#plt.title('SST- ICON 5N-5S daily from 20/1/2020')

plt.title('Precipitation ICON',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.13)
cbar.ax.tick_params(labelsize = 25)
        

        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
plt.savefig('Precipitation_ICON.eps',format='eps',dpi=1000)
# Out:
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:2190: UserWarning: Ignoring netCDF variable 'time' invalid units 'day as %Y%m%d.%f'
#   warnings.warn(msg)
