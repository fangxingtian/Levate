# %%
# To add a new cell, type '# %%'
# To add a new markdown cell, type '# %% [markdown]'
# %%
import iris
import numpy as np
import sys
sys.path.append('/pf/b/b381639/Analysis')
import fxtian_function as fx
from iris.time import PartialDateTime
import datetime
import cf_units
import iris.coord_categorisation
import iris.quickplot as qplt
import matplotlib.pyplot as plt
import numpy as np
import xarray as ar

###############
# plot ERA5
###############
datain = iris.load_cube('/work/bb1153/b381639/ERA5/M1.nc','sd')

#datain.data=datain.data/3600
#datain.data=datain.data*-1
regyonx=datain[0,:,:]
ERA5=regyonx #*100*-86400/9.8

#ERA5=regyonx # *-1/9.8*(100)/(1000)*86400
######################
#plot a map lat vs Lon
########################b
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ERA5) # iris cube to xarray
latm=arr.lat.data              # latm is x-axis
lonm=arr.lon.data # +180             # lonm is y-axis  
#print(arr[0,0,:].data)
#arr = np.roll(arr, 720, axis = 2)

# %%
##################
#(2)set color bar and prepare fig size
#levels1=np.arange(-40,2,2) # min and max of the field; dont use it if not sure
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
#cbar='winter'
#levels1=np.arange(-18.,18.,1.) # min and max of the field; dont use it if not sure
levels1=np.arange(0.,18.,1.)
#cbar='ocean'
#cbar='seismic'
#cbar='jet'
cbar='YlGnBu'
plt.figure(figsize=(30,10))

########
#plot the figure
plt.contourf(lonm,latm,arr,levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr,cmap = cbar)
#plt.title('SST- ICON 5N-5S daily from 20/1/2020')

#plt.title('Moisture convergence ERA5',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.13)
cbar.ax.tick_params(labelsize = 25)
        

        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
#plt.savefig('Moisture_convergence_ERA5.eps',format='eps',dpi=1000)

# %%
# To add a new cell, type '# %%'
# To add a new markdown cell, type '# %% [markdown]'
# %%
import iris
import numpy as np
import sys
sys.path.append('/pf/b/b381639/Analysis')
import fxtian_function as fx
from iris.time import PartialDateTime
import datetime
import cf_units
import iris.coord_categorisation
import iris.quickplot as qplt
import matplotlib.pyplot as plt
import numpy as np


import xarray as ar



###############
# plot ERA5
###############
datain = iris.load_cube('/work/bb1153/b381639/NorESM/QDV_daily_2020_daymean_365.nc')
regyonx=datain[10,:,10,:]

ERA5=regyonx #*-1/9.8*(100)/(1000)*86400 ##(kg m-2 s-1)#* 0.13 #*100000/9.8
#use Pa not hPa
#use kg/kg not g/kg
# Out:
# /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/fileformats/cf.py:584: UserWarning: Missing CF-netCDF formula term variable 'ap', referenced by netCDF variable 'lev'
#   warnings.warn(
# /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/fileformats/cf.py:584: UserWarning: Missing CF-netCDF formula term variable 'b', referenced by netCDF variable 'lev'
#   warnings.warn(
# /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/fileformats/cf.py:584: UserWarning: Missing CF-netCDF formula term variable 'ps', referenced by netCDF variable 'lev'
#   warnings.warn(
# /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/fileformats/cf.py:584: UserWarning: Missing CF-netCDF formula term variable 'ap_bnds', referenced by netCDF variable 'lev_bnds'
#   warnings.warn(
# /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/fileformats/cf.py:584: UserWarning: Missing CF-netCDF formula term variable 'b_bnds', referenced by netCDF variable 'lev_bnds'
#   warnings.warn(
# /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/fileformats/cf.py:584: UserWarning: Missing CF-netCDF formula term variable 'ps', referenced by netCDF variable 'lev_bnds'
#   warnings.warn(

# %%
######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ERA5) # iris cube to xarray
latm=arr.lat.data              # latm is x-axis
lonm=arr.lon.data  #+180            # lonm is y-axis  
#arr = np.roll(arr, 360, axis = 2)
###################
#(2)set color bar and prepare fig size
levels1=np.arange(0.,18,1.) # min and max of the field; dont use it if not sure
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
#cbar='winter'
#levels1=np.arange(-5.,5.,0.5) # min and max of the field; dont use it if not sure
#cbar='ocean'
#cbar='seismic'
#cbar='Spectral_r'
cbar='YlGnBu'
plt.figure(figsize=(30,10))

########
#plot the figure
#plt.contourf(lonm,latm,arr,levels=levels1,cmap = cbar)
plt.contourf(lonm,latm,arr[:,:],cmap = cbar)
#plt.title('SST- ICON 5N-5S daily from 20/1/2020')

#plt.title('Moisture convergent NorESM1.3',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.13)
cbar.ax.tick_params(labelsize = 25)
        

        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
#plt.savefig('Moisture_convergent_NorESM.eps',format='eps',dpi=1000)
# Out:
# /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/fileformats/cf.py:584: UserWarning: Missing CF-netCDF formula term variable 'ap', referenced by netCDF variable 'lev'
#   warnings.warn(
# /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/fileformats/cf.py:584: UserWarning: Missing CF-netCDF formula term variable 'b', referenced by netCDF variable 'lev'
#   warnings.warn(
# /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/fileformats/cf.py:584: UserWarning: Missing CF-netCDF formula term variable 'ps', referenced by netCDF variable 'lev'
#   warnings.warn(
# /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/fileformats/cf.py:584: UserWarning: Missing CF-netCDF formula term variable 'ap_bnds', referenced by netCDF variable 'lev_bnds'
#   warnings.warn(
# /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/fileformats/cf.py:584: UserWarning: Missing CF-netCDF formula term variable 'b_bnds', referenced by netCDF variable 'lev_bnds'
#   warnings.warn(
# /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/fileformats/cf.py:584: UserWarning: Missing CF-netCDF formula term variable 'ps', referenced by netCDF variable 'lev_bnds'
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 55>()
#      50 plt.figure(figsize=(30,10))
#      52 ########
#      53 #plot the figure
#      54 #plt.contourf(lonm,latm,arr,levels=levels1,cmap = cbar)
# ---> 55 plt.contourf(lonm,latm,arr[:,:],cmap = cbar)
#      56 #plt.title('SST- ICON 5N-5S daily from 20/1/2020')
#      57
#      58 #plt.title('Moisture convergent NorESM1.3',fontsize=30)
#      59 cbar=plt.colorbar(orientation='horizontal', pad=0.13)
#
# File /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/matplotlib/pyplot.py:2494, in contourf(data, *args, **kwargs)
#    2492 @_copy_docstring_and_deprecators(Axes.contourf)
#    2493 def contourf(*args, data=None, **kwargs):
# -> 2494     __ret = gca().contourf(
#    2495         *args, **({"data": data} if data is not None else {}),
#    2496         **kwargs)
#    2497     if __ret._A is not None: sci(__ret)  # noqa
#    2498     return __ret
#
# File /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/matplotlib/__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/matplotlib/axes/_axes.py:6313, in Axes.contourf(self, *args, **kwargs)
#    6304 """
#    6305 Plot filled contours.
#    6306
#    (...)
#    6310 %(contour_doc)s
#    6311 """
#    6312 kwargs['filled'] = True
# -> 6313 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6314 self._request_autoscale_view()
#    6315 return contours
#
# File /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/matplotlib/contour.py:812, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, *args, **kwargs)
#     808     self.origin = mpl.rcParams['image.origin']
#     810 self._transform = transform
# --> 812 kwargs = self._process_args(*args, **kwargs)
#     813 self._process_levels()
#     815 self._extend_min = self.extend in ['min', 'both']
#
# File /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/matplotlib/contour.py:1446, in QuadContourSet._process_args(self, corner_mask, *args, **kwargs)
#    1443     corner_mask = mpl.rcParams['contour.corner_mask']
#    1444 self._corner_mask = corner_mask
# -> 1446 x, y, z = self._contour_args(args, kwargs)
#    1448 _mask = ma.getmask(z)
#    1449 if _mask is ma.nomask or not _mask.any():
#
# File /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/matplotlib/contour.py:1485, in QuadContourSet._contour_args(self, args, kwargs)
#    1483     args = args[1:]
#    1484 elif Nargs <= 4:
# -> 1485     x, y, z = self._check_xyz(args[:3], kwargs)
#    1486     args = args[3:]
#    1487 else:
#
# File /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/matplotlib/contour.py:1520, in QuadContourSet._check_xyz(self, args, kwargs)
#    1517 Ny, Nx = z.shape
#    1519 if x.ndim != y.ndim:
# -> 1520     raise TypeError(f"Number of dimensions of x ({x.ndim}) and y "
#    1521                     f"({y.ndim}) do not match")
#    1522 if x.ndim == 1:
#    1523     nx, = x.shape
#
# TypeError: Number of dimensions of x (1) and y (0) do not match

# %%
# To add a new cell, type '# %%'
# To add a new markdown cell, type '# %% [markdown]'
# %%
import iris
import numpy as np
import sys
sys.path.append('/pf/b/b381639/Analysis')
import fxtian_function as fx
from iris.time import PartialDateTime
import datetime
import cf_units
import iris.coord_categorisation
import iris.quickplot as qplt
import matplotlib.pyplot as plt
import numpy as np
import xarray as ar



###############
# plot ERA5
###############
datain = iris.load_cube('/work/bb1153/b381639/NorESM2/MC_daily_2010_daymean_365_TPocean.nc','sd')

datain.data=datain.data #*-1/9.8*86400 

#datain.data=datain.data*-1
regyonx=datain[0,:,:]

ERA5=regyonx

######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ERA5) # iris cube to xarray
latm=arr.lat.data              # latm is x-axis
lonm=arr.lon.data #+180             # lonm is y-axis  
#arr = np.roll(arr, 360, axis = 2)
#################
#(2)set color bar and prepare fig size
levels1=np.arange(0,18,1.) # min and max of the field; dont use it if not sure
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
#cbar='winter'
#levels1=np.arange(-5.,5.,0.5) # min and max of the field; dont use it if not sure
#cbar='ocean'
#cbar='seismic'
#cbar='jet'
cbar='YlGnBu'
plt.figure(figsize=(30,10))

########
#plot the figure
#plt.contourf(lonm,latm,arr[:,:],levels=levels1,cmap = cbar)
plt.contourf(lonm,latm,arr[:,:],cmap = cbar)
#plt.title('SST- ICON 5N-5S daily from 20/1/2020')

plt.title('Moisture convergence NorESM2',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.13)
cbar.ax.tick_params(labelsize = 25)
        

        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
#plt.savefig('Moisture_convergence_NorESM2.eps',format='eps',dpi=1000)
# Out:
# /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/fileformats/cf.py:859: UserWarning: Missing CF-netCDF measure variable 'areacella', referenced by netCDF variable 'sd'
#   warnings.warn(
# (array([-20., -15., -10.,  -5.,   0.,   5.,  10.,  15.,  20.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
###############
# plot ICON
###############
datain = iris.load_cube('/work/bb1153/b381639/model/data_icon/Prec_2020_tropical_ocean_mean_mmday.nc')

datain.data=datain.data

#datain.data=datain.data*-1
regyonx=datain[:,:,:]

ERA5=regyonx

######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ERA5) # iris cube to xarray
latm=arr.latitude.data              # latm is x-axis
lonm=arr.longitude.data    +180         # lonm is y-axis  
arr = np.roll(arr, 720, axis = 2)
##################
#(2)set color bar and prepare fig size
levels1=np.arange(0,18,1.) # min and max of the field; dont use it if not sure
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
#cbar='winter'
#levels1=np.arange(-.5,.5,0.05) # min and max of the field; dont use it if not sure
#cbar='ocean'
#cbar='seismic'
#cbar='jet'
cbar='YlGnBu'
plt.figure(figsize=(30,10))

########
#plot the figure
plt.contourf(lonm,latm,arr[0,:,:],levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr[0,:,:],cmap = cbar)
#plt.title('SST- ICON 5N-5S daily from 20/1/2020')

plt.title('Precipitation ICON',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.13)
cbar.ax.tick_params(labelsize = 25)
        

        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
plt.savefig('Precipitation_ICON.eps',format='eps',dpi=1000)
# Out:
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:2190: UserWarning: Ignoring netCDF variable 'time' invalid units 'day as %Y%m%d.%f'
#   warnings.warn(msg)
