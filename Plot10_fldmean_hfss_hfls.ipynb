# %%
# To add a new cell, type '# %%'
# To add a new markdown cell, type '# %% [markdown]'
# %%
import iris
import numpy as np
import sys
sys.path.append('/pf/b/b381639/Analysis')
import fxtian_function as fx
from iris.time import PartialDateTime
import datetime
import cf_units
import iris.coord_categorisation
import iris.quickplot as qplt
import matplotlib.pyplot as plt
import numpy as np
import xarray as ar



###############
# plot ERA5
###############
datain = iris.load_cube('/work/bb1153/b381639/model/NorEsm_data/hfss_day_NorESM2-LM_historical_fldmean_1990-2014.nc')
datain.data=datain.data
#datain.data=datain.data*-1
regyonx=datain[:,0,0]
hfss=(regyonx-np.mean(regyonx.data))/np.mean(regyonx.data)


datain = iris.load_cube('/work/bb1153/b381639/model/NorEsm_data/hfls_day_NorESM2-LM_historical_fldmean_1990-2014.nc')
datain.data=datain.data
#datain.data=datain.data*-1
regyonx=datain[:,0,0]
hfls=(regyonx-np.mean(regyonx.data))/np.mean(regyonx.data)
# Out:
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/iris/fileformats/cf.py:803: UserWarning: Missing CF-netCDF measure variable 'areacella', referenced by netCDF variable 'hfss'
#   warnings.warn(message % (variable_name, nc_var_name))
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/iris/fileformats/cf.py:803: UserWarning: Missing CF-netCDF measure variable 'areacella', referenced by netCDF variable 'hfls'
#   warnings.warn(message % (variable_name, nc_var_name))

# %%
hfls
# Out:
# <iris 'Cube' of unknown / (kg.s-3) (time: 9125)>

# %%
time=np.arange(1,9126,1)

# %%
plt.figure()
plt.subplot(211)
#plt.plot(hfss.time, hfss, 'bo', t2, f(t2), 'k')
plt.plot(time, hfss.data, 'r-',time,hfls.data, 'b-')

plt.subplot(212)
plt.plot(time[100:260],hfss.data[100:260], 'r-',time[100:260],hfls.data[100:260], 'b-')
plt.savefig('hfls_and_hfss_timeseries_tropical_mean_ocean_NorESM.eps',format='eps',dpi=1000)
plt.show()

# %%
###############
# plot ERA5
###############
datain = iris.load_cube('/work/bb1153/b381639/model/NorEsm_data/hfss_day_NorESM2-LM_historical_fldmean_1990-2014.nc')

#datain.data=datain.data*-1
hfss=datain[:,0,0]



datain = iris.load_cube('/work/bb1153/b381639/model/NorEsm_data/hfls_day_NorESM2-LM_historical_fldmean_1990-2014.nc')

hfls=datain[:,0,0]
# Out:
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/iris/fileformats/cf.py:803: UserWarning: Missing CF-netCDF measure variable 'areacella', referenced by netCDF variable 'hfss'
#   warnings.warn(message % (variable_name, nc_var_name))
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/iris/fileformats/cf.py:803: UserWarning: Missing CF-netCDF measure variable 'areacella', referenced by netCDF variable 'hfls'
#   warnings.warn(message % (variable_name, nc_var_name))

# %%
plt.figure()
plt.subplot(311)
plt.plot(hfls.data, hfss.data, '.')
m, b = np.polyfit(hfls.data, hfss.data,1)
plt.plot(hfls.data, hfls.data*m + b)

plt.subplot(312)
x=hfls[100:160].data
y=hfss[100:160].data
plt.plot(x, y.data, 'r.')
m, b = np.polyfit(x, y,1)
plt.plot(x, x*m + b)

plt.subplot(313)
x=hfls[200:260].data
y=hfss[200:260].data
plt.plot(x, y.data, 'r.')
m, b = np.polyfit(x, y,1)
plt.plot(x, x*m + b)

plt.savefig('hfls_to_hfss_tropical_mean_daily_NorESM.eps',format='eps',dpi=1000)

plt.show()

# %%
# To add a new cell, type '# %%'
# To add a new markdown cell, type '# %% [markdown]'
# %%
import iris
import numpy as np
import sys
sys.path.append('/pf/b/b381639/Analysis')
import fxtian_function as fx
from iris.time import PartialDateTime
import datetime
import cf_units
import iris.coord_categorisation
import iris.quickplot as qplt
import matplotlib.pyplot as plt
import numpy as np
import xarray as ar



###############
# plot ERA5
###############
datain = iris.load_cube('/work/bb1153/b381639/model/NorEsm_data/hfss_day_NorESM2-LM_historical_fldmean_monmean_1990-2014.nc')
datain.data=datain.data
#datain.data=datain.data*-1
regyonx=datain[:,0,0]
hfss=(regyonx-np.mean(regyonx.data))/np.mean(regyonx.data)


datain = iris.load_cube('/work/bb1153/b381639/model/NorEsm_data/hfls_day_NorESM2-LM_historical_fldmean_monmean_1990-2014.nc')
datain.data=datain.data
#datain.data=datain.data*-1
regyonx=datain[:,0,0]
hfls=(regyonx-np.mean(regyonx.data))/np.mean(regyonx.data)
# Out:
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/iris/fileformats/cf.py:803: UserWarning: Missing CF-netCDF measure variable 'areacella', referenced by netCDF variable 'hfss'
#   warnings.warn(message % (variable_name, nc_var_name))
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/iris/fileformats/cf.py:803: UserWarning: Missing CF-netCDF measure variable 'areacella', referenced by netCDF variable 'hfls'
#   warnings.warn(message % (variable_name, nc_var_name))

# %%
time=np.arange(1,301,1)

# %%
hfss.data
# Out:
# masked_array(data=[0.048232268542051315, 0.009023516438901424,
#                    -0.029902338981628418, -0.04700489342212677,
#                    0.009503967128694057, 0.07405178993940353,
#                    0.07235553115606308, 0.051335062831640244,
#                    0.05563369765877724, -0.009721888229250908,
#                    0.05541801080107689, 0.021425826475024223,
#                    0.05539271607995033, -0.008111953735351562,
#                    -0.07632219046354294, -0.043733321130275726,
#                    -0.04489368200302124, -0.002136308467015624,
#                    0.07418561726808548, 0.016589846462011337,
#                    0.04421994835138321, 0.010383600369095802,
#                    0.04484276846051216, 0.059083178639411926,
#                    0.023006852716207504, -0.048575542867183685,
#                    -0.05292075499892235, -0.06539684534072876,
#                    0.007922743447124958, 0.061263307929039,
# ...

# %%
plt.figure()
plt.subplot(211)
#plt.plot(hfss.time, hfss, 'bo', t2, f(t2), 'k')
plt.plot(time, hfss.data, 'r-',time,hfls.data, 'b-')

plt.subplot(212)
plt.plot(time[0:60],hfss.data[0:60], 'r-',time[0:60],hfls.data[0:60], 'b-')
plt.show()

# %%
###############
# plot tropical mean
###############
datain = iris.load_cube('/work/bb1153/b381639/model/NorEsm_data/hfss_day_NorESM2-LM_historical_fldmean_monmean_1990-2014.nc')
datain.data=datain.data
#datain.data=datain.data*-1
regyonx=datain[:,0,0]
hfss=regyonx


datain = iris.load_cube('/work/bb1153/b381639/model/NorEsm_data/hfls_day_NorESM2-LM_historical_fldmean_monmean_1990-2014.nc')
datain.data=datain.data
#datain.data=datain.data*-1
regyonx=datain[:,0,0]
hfls=regyonx


plt.plot(hfls.data, hfss.data, '.')
m, b = np.polyfit(hfls.data, hfss.data,1)
plt.plot(hfls.data, hfls.data*m + b)
# Out:
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/iris/fileformats/cf.py:803: UserWarning: Missing CF-netCDF measure variable 'areacella', referenced by netCDF variable 'hfss'
#   warnings.warn(message % (variable_name, nc_var_name))
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/iris/fileformats/cf.py:803: UserWarning: Missing CF-netCDF measure variable 'areacella', referenced by netCDF variable 'hfls'
#   warnings.warn(message % (variable_name, nc_var_name))

# %%
x=hfls[200:260].data
y=hfss[200:260].data
plt.plot(x, y.data, 'r.')
m, b = np.polyfit(x, y,1)
plt.plot(x, x*m + b)

# %%
x=hfls[:160].data
y=hfss[:160].data
plt.plot(x, y.data, 'r.')
m, b = np.polyfit(x, y,1)
plt.plot(x, x*m + b)

# %%
plt.figure()
plt.subplot(311)
plt.plot(hfls.data, hfss.data, '.')
m, b = np.polyfit(hfls.data, hfss.data,1)
plt.plot(hfls.data, hfls.data*m + b)

plt.subplot(312)
x=hfls[100:160].data
y=hfss[100:160].data
plt.plot(x, y.data, 'r.')
m, b = np.polyfit(x, y,1)
plt.plot(x, x*m + b)

plt.subplot(313)
x=hfls[200:260].data
y=hfss[200:260].data
plt.plot(x, y.data, 'r.')
m, b = np.polyfit(x, y,1)
plt.plot(x, x*m + b)

plt.savefig('hfls_to_hfss_tropical_mean_ocean_NorESM.eps',format='eps',dpi=1000)

plt.show()

# %%
# To add a new cell, type '# %%'
# To add a new markdown cell, type '# %% [markdown]'
# %%
import iris
import numpy as np
import sys
sys.path.append('/pf/b/b381639/Analysis')
import fxtian_function as fx
from iris.time import PartialDateTime
import datetime
import cf_units
import iris.coord_categorisation
import iris.quickplot as qplt
import matplotlib.pyplot as plt
import numpy as np
import xarray as ar



###############
# plot ERA5
###############
datain = iris.load_cube('/work/bb1153/b381639/model/NorEsm_data/hfss_day_NorESM2-LM_historical_fldmean_1850-2014.nc')
datain.data=datain.data
#datain.data=datain.data*-1
regyonx=datain[:,0,0]
hfss=(regyonx-np.mean(regyonx.data))/np.mean(regyonx.data)


datain = iris.load_cube('/work/bb1153/b381639/model/NorEsm_data/hfls_day_NorESM2-LM_historical_fldmean_1850-2014.nc')
datain.data=datain.data
#datain.data=datain.data*-1
regyonx=datain[:,0,0]
hfls=(regyonx-np.mean(regyonx.data))/np.mean(regyonx.data)
# Out:
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/iris/fileformats/cf.py:803: UserWarning: Missing CF-netCDF measure variable 'areacella', referenced by netCDF variable 'hfss'
#   warnings.warn(message % (variable_name, nc_var_name))
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/iris/fileformats/cf.py:803: UserWarning: Missing CF-netCDF measure variable 'areacella', referenced by netCDF variable 'hfls'
#   warnings.warn(message % (variable_name, nc_var_name))

# %%
hfls
time=np.arange(1850,2015,1)

# %%
hfls
# Out:
# <iris 'Cube' of unknown / (kg.s-3) (time: 165)>

# %%
plt.figure()
plt.subplot(211)
#plt.plot(hfss.time, hfss, 'bo', t2, f(t2), 'k')
plt.plot(time, hfss.data, 'r-',time,hfls.data, 'b-')

plt.subplot(212)
plt.plot(time[100:],hfss.data[100:], 'r-',time[100:],hfls.data[100:], 'b-')
plt.savefig('hfls_to_hfss_tropicalmean_timseries_NorESM_yearly_1850-2014.eps',format='eps',dpi=1000)
plt.show()

# %%
# To add a new cell, type '# %%'
# To add a new markdown cell, type '# %% [markdown]'
# %%
import iris
import numpy as np
import sys
sys.path.append('/pf/b/b381639/Analysis')
import fxtian_function as fx
from iris.time import PartialDateTime
import datetime
import cf_units
import iris.coord_categorisation
import iris.quickplot as qplt
import matplotlib.pyplot as plt
import numpy as np
import xarray as ar


###############
# plot r3i1p1f1
###############
hfss = iris.load_cube('/work/bb1153/b381639/model/NorEsm_data/hfss_day_NorESM2-LM_historical_fldmean_1850-2014.nc')
hfls = iris.load_cube('/work/bb1153/b381639/model/NorEsm_data/hfls_day_NorESM2-LM_historical_fldmean_1850-2014.nc')


time=np.arange(1850,2015,1)


m2=list(0 for i in range(0,145)) 
b2=list(0 for i in range(0,145)) 

for i in range(0, 145, 1):
    x=hfls[i:i+20,0,0].data
    y=hfss[i:i+20,0,0].data
#    plt.plot(x, y, '.')
    m2[i], b2[i] = np.polyfit(x, y,1)



m4=list(0 for i in range(0,125)) 
b4=list(0 for i in range(0,125)) 

for i in range(0, 125, 1):
    x=hfls[i:i+40,0,0].data
    y=hfss[i:i+40,0,0].data
#    plt.plot(x, y, '.')
    m4[i], b4[i] = np.polyfit(x, y,1)



m=list(0 for i in range(0,100)) 
b=list(0 for i in range(0,100)) 

for i in range(0, 100, 1):
    x=hfls[i:i+65,0,0].data
    y=hfss[i:i+65,0,0].data
#    plt.plot(x, y, '.')
    m[i], b[i] = np.polyfit(x, y,1)

plt.subplot(111)
plt.plot(time[65:],m, 'r-',label='65year')
plt.plot(time[40:],m4, 'b-', label='40year')
plt.plot(time[20:],m2, 'g-',label='20year')


plt.grid(axis='x', color='0.95')
plt.legend()
plt.title('angular coefficient r3i1p1f1')

plt.savefig('angular_coefficient_1850-2014_r3i1p1f1.eps',format='eps',dpi=1000)
plt.show()
# Out:
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/iris/fileformats/cf.py:803: UserWarning: Missing CF-netCDF measure variable 'areacella', referenced by netCDF variable 'hfss'
#   warnings.warn(message % (variable_name, nc_var_name))
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/iris/fileformats/cf.py:803: UserWarning: Missing CF-netCDF measure variable 'areacella', referenced by netCDF variable 'hfls'
#   warnings.warn(message % (variable_name, nc_var_name))
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
###############
# plot r3i1p1f1
###############
hfss = iris.load_cube('/work/bb1153/b381639/model/NorEsm_data/hfss_day_NorESM2-LM_historical_r1i1p1f1_fldmean_1850-2014.nc')
hfls = iris.load_cube('/work/bb1153/b381639/model/NorEsm_data/hfls_day_NorESM2-LM_historical_r1i1p1f1_fldmean_1850-2014.nc')


time=np.arange(1850,2015,1)


m2=list(0 for i in range(0,145)) 
b2=list(0 for i in range(0,145)) 

for i in range(0, 145, 1):
    x=hfls[i:i+20,0,0].data
    y=hfss[i:i+20,0,0].data
#    plt.plot(x, y, '.')
    m2[i], b2[i] = np.polyfit(x, y,1)



m4=list(0 for i in range(0,125)) 
b4=list(0 for i in range(0,125)) 

for i in range(0, 125, 1):
    x=hfls[i:i+40,0,0].data
    y=hfss[i:i+40,0,0].data
#    plt.plot(x, y, '.')
    m4[i], b4[i] = np.polyfit(x, y,1)



m=list(0 for i in range(0,100)) 
b=list(0 for i in range(0,100)) 

for i in range(0, 100, 1):
    x=hfls[i:i+65,0,0].data
    y=hfss[i:i+65,0,0].data
#    plt.plot(x, y, '.')
    m[i], b[i] = np.polyfit(x, y,1)

plt.subplot(111)
plt.plot(time[65:],m, 'r-',label='65year')
plt.plot(time[40:],m4, 'b-', label='40year')
plt.plot(time[20:],m2, 'g-',label='20year')


plt.grid(axis='x', color='0.95')
plt.legend()
plt.title('angular coefficient r1i1p1f1')

plt.savefig('angular_coefficient_1850-2014_r1i1p1f1.eps',format='eps',dpi=1000)
plt.show()
# Out:
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/iris/fileformats/cf.py:803: UserWarning: Missing CF-netCDF measure variable 'areacella', referenced by netCDF variable 'hfss'
#   warnings.warn(message % (variable_name, nc_var_name))
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/iris/fileformats/cf.py:803: UserWarning: Missing CF-netCDF measure variable 'areacella', referenced by netCDF variable 'hfls'
#   warnings.warn(message % (variable_name, nc_var_name))
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
###############
# plot r3i1p1f1
###############
hfss = iris.load_cube('/work/bb1153/b381639/model/NorEsm_data/hfss_day_NorESM2-LM_historical_r2i1p1f1_fldmean_1850-2014.nc')
hfls = iris.load_cube('/work/bb1153/b381639/model/NorEsm_data/hfls_day_NorESM2-LM_historical_r2i1p1f1_fldmean_1850-2014.nc')


time=np.arange(1850,2015,1)


m2=list(0 for i in range(0,145)) 
b2=list(0 for i in range(0,145)) 

for i in range(0, 145, 1):
    x=hfls[i:i+20,0,0].data
    y=hfss[i:i+20,0,0].data
#    plt.plot(x, y, '.')
    m2[i], b2[i] = np.polyfit(x, y,1)



m4=list(0 for i in range(0,125)) 
b4=list(0 for i in range(0,125)) 

for i in range(0, 125, 1):
    x=hfls[i:i+40,0,0].data
    y=hfss[i:i+40,0,0].data
#    plt.plot(x, y, '.')
    m4[i], b4[i] = np.polyfit(x, y,1)



m=list(0 for i in range(0,100)) 
b=list(0 for i in range(0,100)) 

for i in range(0, 100, 1):
    x=hfls[i:i+65,0,0].data
    y=hfss[i:i+65,0,0].data
#    plt.plot(x, y, '.')
    m[i], b[i] = np.polyfit(x, y,1)

plt.subplot(111)
plt.plot(time[65:],m, 'r-',label='65year')
plt.plot(time[40:],m4, 'b-', label='40year')
plt.plot(time[20:],m2, 'g-',label='20year')


plt.grid(axis='x', color='0.95')
plt.legend()
plt.title('angular coefficient r2i1p1f1')

plt.savefig('angular_coefficient_1850-2014_r2i1p1f1.eps',format='eps',dpi=1000)
plt.show()
# Out:
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/iris/fileformats/cf.py:803: UserWarning: Missing CF-netCDF measure variable 'areacella', referenced by netCDF variable 'hfss'
#   warnings.warn(message % (variable_name, nc_var_name))
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/iris/fileformats/cf.py:803: UserWarning: Missing CF-netCDF measure variable 'areacella', referenced by netCDF variable 'hfls'
#   warnings.warn(message % (variable_name, nc_var_name))
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
x=hfls[:,0,0].data
y=hfss[:,0,0].data
plt.plot(x, y, '.')
m, b = np.polyfit(x, y,1)
plt.plot(x, x*m + b)
plt.savefig('hfls_to_hfss_tropicalmean_NorESM_yearly_1850-2014.eps',format='eps',dpi=1000)
plt.show()

# %%
m
# Out:
# -0.0036940623607190992

# %%
# To add a new cell, type '# %%'
# To add a new markdown cell, type '# %% [markdown]'
# %%
import iris
import numpy as np
import sys
sys.path.append('/pf/b/b381639/Analysis')
import fxtian_function as fx
from iris.time import PartialDateTime
import datetime
import cf_units
import iris.coord_categorisation
import iris.quickplot as qplt
import matplotlib.pyplot as plt
import numpy as np
import xarray as ar



###############
# plot ERA5
###############
datain = iris.load_cube('/work/bb1153/b381639/model/NorEsm_data/hfss_day_NorESM2-LM_historical_fldmean_monmean_1990-2014.nc')

datain.data=datain.data

#datain.data=datain.data*-1
regyonx=datain[:,:,:]

ERA5=regyonx

######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ERA5) # iris cube to xarray
latm=arr.latitude.data              # latm is x-axis
lonm=arr.longitude.data             # lonm is y-axis  

##################
#(2)set color bar and prepare fig size
#levels1=np.arange(-40,0,2) # min and max of the field; dont use it if not sure
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
#cbar='winter'
levels1=np.arange(-.5,.5,0.05) # min and max of the field; dont use it if not sure
#cbar='ocean'
#cbar='seismic'
cbar='jet'
plt.figure(figsize=(30,10))

########
#plot the figure
plt.contourf(lonm,latm,arr[0,:,:],levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr[0,:,:],cmap = cbar)
#plt.title('SST- ICON 5N-5S daily from 20/1/2020')

plt.title('regress sst onto windspeed ERA5',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.13)
cbar.ax.tick_params(labelsize = 25)
        

        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
plt.savefig('regress_sst_on_wind_ERA5.eps',format='eps',dpi=1000)
# Out:
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/iris/fileformats/cf.py:803: UserWarning: Missing CF-netCDF measure variable 'areacella', referenced by netCDF variable 'hfss'
#   warnings.warn(message % (variable_name, nc_var_name))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-a7e7d21cad4a> in <module>
#      36 #(1) get x-axis and y axis
#      37 arr=ar.DataArray.from_iris(ERA5) # iris cube to xarray
# ---> 38 latm=arr.latitude.data              # latm is x-axis
#      39 lonm=arr.longitude.data             # lonm is y-axis
#      40
#
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/xarray/core/common.py in __getattr__(self, name)
#     244                 with suppress(KeyError):
#     245                     return source[name]
# --> 246         raise AttributeError(
# ...

# %%
###############
# plot ICON
###############
datain = iris.load_cube('/work/bb1153/b381639/model/data_icon/regress_sst_sfcwind.nc')

datain.data=datain.data

#datain.data=datain.data*-1
regyonx=datain[:,:,:]

ERA5=regyonx

######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ERA5) # iris cube to xarray
latm=arr.latitude.data              # latm is x-axis
lonm=arr.longitude.data             # lonm is y-axis  

##################
#(2)set color bar and prepare fig size
#levels1=np.arange(-40,0,2) # min and max of the field; dont use it if not sure
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
#cbar='winter'
levels1=np.arange(-.5,.5,0.05) # min and max of the field; dont use it if not sure
#cbar='ocean'
#cbar='seismic'
cbar='jet'
plt.figure(figsize=(30,10))

########
#plot the figure
plt.contourf(lonm,latm,arr[0,:,:],levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr[0,:,:],cmap = cbar)
#plt.title('SST- ICON 5N-5S daily from 20/1/2020')

plt.title('regress sst onto windspeed ICON',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.13)
cbar.ax.tick_params(labelsize = 25)
        

        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
plt.savefig('regress_sst_on_wind_ICON.eps',format='eps',dpi=1000)
