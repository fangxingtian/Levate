# %%
# To add a new cell, type '# %%'
# To add a new markdown cell, type '# %% [markdown]'
# %%
import iris
import numpy as np
import sys
#sys.path.append('/pf/b/b381639/Analysis')
#import fxtian_function as fx
from iris.time import PartialDateTime
import datetime
import cf_units
import iris.coord_categorisation
import iris.quickplot as qplt
import matplotlib.pyplot as plt
import numpy as np
import xarray as ar

###############
# plot ERA5
###############
datain = iris.load_cube('/work/bb1153/b381639/ERA5/CLDHML.nc','hcc')

#datain.data=datain.data/3600

#datain.data=datain.data*-1
regyonx=datain[0,:,:]

ERA5=regyonx #/-86400

print(ERA5)
######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ERA5) # iris cube to xarray
latm=arr.latitude.data              # latm is x-axis
lonm=arr.longitude.data    #+180         # lonm is y-axis  
#arr = np.roll(arr, 720, axis = 2)
#print(arr[0,0,:].data)
##################
#(2)set color bar and prepare fig size
#levels1=np.arange(-40,2,2) # min and max of the field; dont use it if not sure
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
#cbar='winter'
levels1=np.arange(0,1,0.1) # min and max of the field; dont use it if not sure
#cbar='ocean'
cbar='Spectral_r'
#cbar='YlGnBu'
plt.figure(figsize=(30,10))

########
#plot the figure
plt.contourf(lonm,latm,arr,levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr,cmap = cbar)
#plt.title('SST- ICON 5N-5S daily from 20/1/2020')

plt.title('CLD High Cloud Cover ERA5',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.13)
cbar.ax.tick_params(labelsize = 25)
        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
plt.savefig('CLDHCC_ERA5.eps',format='eps',dpi=1000)
# Out:
# /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/fileformats/_nc_load_rules/helpers.py:645: UserWarning: Ignoring netCDF variable 'lcc' invalid units '(0 - 1)'
#   warnings.warn(msg)
# ut_scale(): NULL factor argument
# ut_are_convertible(): NULL unit argument
# /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/fileformats/_nc_load_rules/helpers.py:645: UserWarning: Ignoring netCDF variable 'mcc' invalid units '(0 - 1)'
#   warnings.warn(msg)
# ut_scale(): NULL factor argument
# ut_are_convertible(): NULL unit argument
# /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/fileformats/_nc_load_rules/helpers.py:645: UserWarning: Ignoring netCDF variable 'hcc' invalid units '(0 - 1)'
#   warnings.warn(msg)
# ut_scale(): NULL factor argument
# ut_are_convertible(): NULL unit argument
# High cloud cover / (unknown)        (latitude: 401; longitude: 961)
#     Dimension coordinates:
#         latitude                             x               -
#         longitude                            -               x
#     Scalar coordinates:
#         time                        2000-06-16 00:00:00, bound=(1979-01-01 00:00:00, 2021-12-01 00:00:00)
#     Cell methods:
#         mean                        time
#     Attributes:
#         CDI                         'Climate Data Interface version 1.9.10 (https://mpimet.mpg.de/cdi)'
#         CDO                         'Climate Data Operators version 1.9.10 (https://mpimet.mpg.de/cdo)'
#         Conventions                 'CF-1.6'
#         history                     'Fri Jun 10 15:41:51 2022: cdo sellonlatbox,30,270,-50,50 /work/bb1153/b381639/ERA5/CLDHML_lm.nc...
#         invalid_units               '(0 - 1)'

# %%
# To add a new cell, type '# %%'
# To add a new markdown cell, type '# %% [markdown]'
# %%
import iris
import numpy as np
import sys
#sys.path.append('/pf/b/b381639/Analysis')
#import fxtian_function as fx
from iris.time import PartialDateTime
import datetime
import cf_units
import iris.coord_categorisation
import iris.quickplot as qplt
import matplotlib.pyplot as plt
import numpy as np
import xarray as ar

###############
# plot ERA5
###############
datain = iris.load_cube('/work/bb1153/b381639/ERA5/CLDHML.nc','mcc')

#datain.data=datain.data/3600

#datain.data=datain.data*-1
regyonx=datain[0,:,:]

ERA5=regyonx #/-86400

print(ERA5)
######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ERA5) # iris cube to xarray
latm=arr.latitude.data              # latm is x-axis
lonm=arr.longitude.data    #+180         # lonm is y-axis  
#arr = np.roll(arr, 720, axis = 2)
#print(arr[0,0,:].data)
##################
#(2)set color bar and prepare fig size
#levels1=np.arange(-40,2,2) # min and max of the field; dont use it if not sure
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
#cbar='winter'
levels1=np.arange(0,1,0.1) # min and max of the field; dont use it if not sure
#cbar='ocean'
cbar='Spectral_r'
#cbar='YlGnBu'
plt.figure(figsize=(30,10))

########
#plot the figure
plt.contourf(lonm,latm,arr,levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr,cmap = cbar)
#plt.title('SST- ICON 5N-5S daily from 20/1/2020')

plt.title('CLD Medium Cloud Cover ERA5',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.13)
cbar.ax.tick_params(labelsize = 25)
        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
plt.savefig('CLDMCC_ERA5.eps',format='eps',dpi=1000)
# Out:
# /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/fileformats/_nc_load_rules/helpers.py:645: UserWarning: Ignoring netCDF variable 'lcc' invalid units '(0 - 1)'
#   warnings.warn(msg)
# ut_scale(): NULL factor argument
# ut_are_convertible(): NULL unit argument
# /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/fileformats/_nc_load_rules/helpers.py:645: UserWarning: Ignoring netCDF variable 'mcc' invalid units '(0 - 1)'
#   warnings.warn(msg)
# ut_scale(): NULL factor argument
# ut_are_convertible(): NULL unit argument
# /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/fileformats/_nc_load_rules/helpers.py:645: UserWarning: Ignoring netCDF variable 'hcc' invalid units '(0 - 1)'
#   warnings.warn(msg)
# ut_scale(): NULL factor argument
# ut_are_convertible(): NULL unit argument
# Medium cloud cover / (unknown)      (latitude: 401; longitude: 961)
#     Dimension coordinates:
#         latitude                             x               -
#         longitude                            -               x
#     Scalar coordinates:
#         time                        2000-06-16 00:00:00, bound=(1979-01-01 00:00:00, 2021-12-01 00:00:00)
#     Cell methods:
#         mean                        time
#     Attributes:
#         CDI                         'Climate Data Interface version 1.9.10 (https://mpimet.mpg.de/cdi)'
#         CDO                         'Climate Data Operators version 1.9.10 (https://mpimet.mpg.de/cdo)'
#         Conventions                 'CF-1.6'
#         history                     'Fri Jun 10 15:41:51 2022: cdo sellonlatbox,30,270,-50,50 /work/bb1153/b381639/ERA5/CLDHML_lm.nc...
#         invalid_units               '(0 - 1)'

# %%
# To add a new cell, type '# %%'
# To add a new markdown cell, type '# %% [markdown]'
# %%
import iris
import numpy as np
import sys
#sys.path.append('/pf/b/b381639/Analysis')
#import fxtian_function as fx
from iris.time import PartialDateTime
import datetime
import cf_units
import iris.coord_categorisation
import iris.quickplot as qplt
import matplotlib.pyplot as plt
import numpy as np
import xarray as ar

###############
# plot ERA5
###############
datain = iris.load_cube('/work/bb1153/b381639/ERA5/CLDHML.nc','lcc')

#datain.data=datain.data/3600

#datain.data=datain.data*-1
regyonx=datain[0,:,:]

ERA5=regyonx #/-86400

print(ERA5)
######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ERA5) # iris cube to xarray
latm=arr.latitude.data              # latm is x-axis
lonm=arr.longitude.data    #+180         # lonm is y-axis  
#arr = np.roll(arr, 720, axis = 2)
#print(arr[0,0,:].data)
##################
#(2)set color bar and prepare fig size
#levels1=np.arange(-40,2,2) # min and max of the field; dont use it if not sure
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
#cbar='winter'
levels1=np.arange(0,1,0.1) # min and max of the field; dont use it if not sure
#cbar='ocean'
cbar='Spectral_r'
#cbar='YlGnBu'
plt.figure(figsize=(30,10))

########
#plot the figure
plt.contourf(lonm,latm,arr,levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr,cmap = cbar)
#plt.title('SST- ICON 5N-5S daily from 20/1/2020')

plt.title('CLD Low Cloud Cover ERA5',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.13)
cbar.ax.tick_params(labelsize = 25)
        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
plt.savefig('CLDLCC_ERA5.eps',format='eps',dpi=1000)
# Out:
# /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/fileformats/_nc_load_rules/helpers.py:645: UserWarning: Ignoring netCDF variable 'lcc' invalid units '(0 - 1)'
#   warnings.warn(msg)
# ut_scale(): NULL factor argument
# ut_are_convertible(): NULL unit argument
# /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/fileformats/_nc_load_rules/helpers.py:645: UserWarning: Ignoring netCDF variable 'mcc' invalid units '(0 - 1)'
#   warnings.warn(msg)
# ut_scale(): NULL factor argument
# ut_are_convertible(): NULL unit argument
# /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/fileformats/_nc_load_rules/helpers.py:645: UserWarning: Ignoring netCDF variable 'hcc' invalid units '(0 - 1)'
#   warnings.warn(msg)
# ut_scale(): NULL factor argument
# ut_are_convertible(): NULL unit argument
# Low cloud cover / (unknown)         (latitude: 401; longitude: 961)
#     Dimension coordinates:
#         latitude                             x               -
#         longitude                            -               x
#     Scalar coordinates:
#         time                        2000-06-16 00:00:00, bound=(1979-01-01 00:00:00, 2021-12-01 00:00:00)
#     Cell methods:
#         mean                        time
#     Attributes:
#         CDI                         'Climate Data Interface version 1.9.10 (https://mpimet.mpg.de/cdi)'
#         CDO                         'Climate Data Operators version 1.9.10 (https://mpimet.mpg.de/cdo)'
#         Conventions                 'CF-1.6'
#         history                     'Fri Jun 10 15:41:51 2022: cdo sellonlatbox,30,270,-50,50 /work/bb1153/b381639/ERA5/CLDHML_lm.nc...
#         invalid_units               '(0 - 1)'

# %%
# To add a new cell, type '# %%'
# To add a new markdown cell, type '# %% [markdown]'
# %%
import iris
import numpy as np
import sys
#sys.path.append('/pf/b/b381639/Analysis')
#import fxtian_function as fx
from iris.time import PartialDateTime
import datetime
import cf_units
import iris.coord_categorisation
import iris.quickplot as qplt
import matplotlib.pyplot as plt
import numpy as np


import xarray as ar



###############
# plot ERA5
###############
datain = iris.load_cube('/work/bb1153/b381639/NorESM/CLDHGH.nc')
#datain.data=datain.data/3600

datain.data=datain.data
regyonx=datain[0,:,:]

ERA5=regyonx #*-1
print(ERA5)

######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ERA5) # iris cube to xarray
latm=arr.latitude.data              # latm is x-axis
lonm=arr.longitude.data # +180           # lonm is y-axis  
#arr = np.roll(arr, 360, axis = 2)
###################
#(2)set color bar and prepare fig size
levels1=np.arange(0,1,0.1) # min and max of the field; dont use it if not sure
#levels1=np.arange(-0.1,0.11,0.01)
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
#cbar='winter'
#levels1=np.arange(-5.,5.,0.5) # min and max of the field; dont use it if not sure
#cbar='ocean'
#cbar='seismic'
cbar='Spectral_r'
plt.figure(figsize=(30,10))

########
#plot the figure
plt.contourf(lonm,latm,arr,levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr,cmap = cbar)
#plt.title('SST- ICON 5N-5S daily from 20/1/2020')

plt.title('High cloud cover NorESM1.3',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.13)
cbar.ax.tick_params(labelsize = 25)
        

        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
plt.savefig('CLDHGH_NorESM.eps',format='eps',dpi=1000)
# Out:
# Vertically-integrated high cloud / (1) (latitude: 200; longitude: 480)
#     Dimension coordinates:
#         latitude                                x               -
#         longitude                               -               x
#     Scalar coordinates:
#         time                           0150-07-02 00:00:00, bound=(0150-01-01 00:00:00, 0150-12-31 00:00:00)
#     Cell methods:
#         mean                           time
#     Attributes:
#         CDI                            'Climate Data Interface version 1.9.10 (https://mpimet.mpg.de/cdi)'
#         CDO                            'Climate Data Operators version 1.9.10 (https://mpimet.mpg.de/cdo)'
#         Conventions                    'CF-1.6'
#         history                        'Fri Jun 10 15:41:51 2022: cdo sellonlatbox,30,270,-50,50 /work/bb1153/b381639/NorESM/CLDHGH_150_timmean_lm.nc...

# %%
# To add a new cell, type '# %%'
# To add a new markdown cell, type '# %% [markdown]'
# %%
import iris
import numpy as np
import sys
#sys.path.append('/pf/b/b381639/Analysis')
#import fxtian_function as fx
from iris.time import PartialDateTime
import datetime
import cf_units
import iris.coord_categorisation
import iris.quickplot as qplt
import matplotlib.pyplot as plt
import numpy as np


import xarray as ar



###############
# plot ERA5
###############
datain = iris.load_cube('/work/bb1153/b381639/NorESM/CLDMED.nc')
#datain.data=datain.data/3600

datain.data=datain.data
regyonx=datain[0,:,:]

ERA5=regyonx #*-1
print(ERA5)

######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ERA5) # iris cube to xarray
latm=arr.latitude.data              # latm is x-axis
lonm=arr.longitude.data # +180           # lonm is y-axis  
#arr = np.roll(arr, 360, axis = 2)
###################
#(2)set color bar and prepare fig size
levels1=np.arange(0,1,0.1) # min and max of the field; dont use it if not sure
#levels1=np.arange(-0.1,0.11,0.01)
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
#cbar='winter'
#levels1=np.arange(-5.,5.,0.5) # min and max of the field; dont use it if not sure
#cbar='ocean'
#cbar='seismic'
cbar='Spectral_r'
plt.figure(figsize=(30,10))

########
#plot the figure
plt.contourf(lonm,latm,arr,levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr,cmap = cbar)
#plt.title('SST- ICON 5N-5S daily from 20/1/2020')

plt.title('Medium level cloud cover NorESM1.3',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.13)
cbar.ax.tick_params(labelsize = 25)
        

        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
plt.savefig('CLDMED_NorESM.eps',format='eps',dpi=1000)
# Out:
# Vertically-integrated mid-level cloud / (1) (latitude: 200; longitude: 480)
#     Dimension coordinates:
#         latitude                                     x               -
#         longitude                                    -               x
#     Scalar coordinates:
#         time                                0150-07-02 00:00:00, bound=(0150-01-01 00:00:00, 0150-12-31 00:00:00)
#     Cell methods:
#         mean                                time
#     Attributes:
#         CDI                                 'Climate Data Interface version 1.9.10 (https://mpimet.mpg.de/cdi)'
#         CDO                                 'Climate Data Operators version 1.9.10 (https://mpimet.mpg.de/cdo)'
#         Conventions                         'CF-1.6'
#         history                             'Fri Jun 10 15:41:51 2022: cdo sellonlatbox,30,270,-50,50 /work/bb1153/b381639/NorESM/CLDMED_150_timmean_lm.nc...

# %%
# To add a new cell, type '# %%'
# To add a new markdown cell, type '# %% [markdown]'
# %%
import iris
import numpy as np
import sys
#sys.path.append('/pf/b/b381639/Analysis')
#import fxtian_function as fx
from iris.time import PartialDateTime
import datetime
import cf_units
import iris.coord_categorisation
import iris.quickplot as qplt
import matplotlib.pyplot as plt
import numpy as np


import xarray as ar



###############
# plot ERA5
###############
datain = iris.load_cube('/work/bb1153/b381639/NorESM/CLDLOW.nc')
#datain.data=datain.data/3600

datain.data=datain.data
regyonx=datain[0,:,:]

ERA5=regyonx #*-1
print(ERA5)

######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ERA5) # iris cube to xarray
latm=arr.latitude.data              # latm is x-axis
lonm=arr.longitude.data # +180           # lonm is y-axis  
#arr = np.roll(arr, 360, axis = 2)
###################
#(2)set color bar and prepare fig size
levels1=np.arange(0,1,0.1) # min and max of the field; dont use it if not sure
#levels1=np.arange(-0.1,0.11,0.01)
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
#cbar='winter'
#levels1=np.arange(-5.,5.,0.5) # min and max of the field; dont use it if not sure
#cbar='ocean'
#cbar='seismic'
cbar='Spectral_r'
plt.figure(figsize=(30,10))

########
#plot the figure
plt.contourf(lonm,latm,arr,levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr,cmap = cbar)
#plt.title('SST- ICON 5N-5S daily from 20/1/2020')

plt.title('Low level cloud cover NorESM1.3',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.13)
cbar.ax.tick_params(labelsize = 25)
        

        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
plt.savefig('CLDLOW_NorESM.eps',format='eps',dpi=1000)
# Out:
# Vertically-integrated low cloud / (1) (latitude: 200; longitude: 480)
#     Dimension coordinates:
#         latitude                               x               -
#         longitude                              -               x
#     Scalar coordinates:
#         time                          0150-07-02 00:00:00, bound=(0150-01-01 00:00:00, 0150-12-31 00:00:00)
#     Cell methods:
#         mean                          time
#     Attributes:
#         CDI                           'Climate Data Interface version 1.9.10 (https://mpimet.mpg.de/cdi)'
#         CDO                           'Climate Data Operators version 1.9.10 (https://mpimet.mpg.de/cdo)'
#         Conventions                   'CF-1.6'
#         history                       'Fri Jun 10 15:41:51 2022: cdo sellonlatbox,30,270,-50,50 /work/bb1153/b381639/NorESM/CLDLOW_150_timmean_lm.nc...

# %%
# To add a new cell, type '# %%'
# To add a new markdown cell, type '# %% [markdown]'
# %%
import iris
import numpy as np
import sys
#sys.path.append('/pf/b/b381639/Analysis')
#import fxtian_function as fx
from iris.time import PartialDateTime
import datetime
import cf_units
import iris.coord_categorisation
import iris.quickplot as qplt
import matplotlib.pyplot as plt
import numpy as np


import xarray as ar



###############
# plot ERA5
###############
datain = iris.load_cube('/work/bb1153/b381639/NorESM2/clt.nc')

#datain.data=datain.data/3600

#datain.data=datain.data*-1
regyonx=datain[0,:,:]

ERA5=regyonx #*-1

######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ERA5) # iris cube to xarray
latm=arr.lat.data              # latm is x-axis
lonm=arr.lon.data #+180             # lonm is y-axis  
# arr = np.roll(arr, 360, axis = 2)
##################
#(2)set color bar and prepare fig size
levels1=np.arange(195,315,10) # min and max of the field; dont use it if not sure
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
cbar='winter'
#levels1=np.arange(-5.,5.,0.5) # min and max of the field; dont use it if not sure
#cbar='ocean'
#cbar='seismic'
cbar='Spectral_r'
plt.figure(figsize=(30,10))

########
#plot the figure
#plt.contourf(lonm,latm,arr,levels=levels1,cmap = cbar)
plt.contourf(lonm,latm,arr,cmap = cbar)
#plt.title('SST- ICON 5N-5S daily from 20/1/2020')

plt.title('CLDTOT NorESM2',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.13)
cbar.ax.tick_params(labelsize = 25)
        

        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
plt.savefig('CLDTOT_NorESM2.eps',format='eps',dpi=1000)
# Out:
# /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/iris/fileformats/cf.py:859: UserWarning: Missing CF-netCDF measure variable 'areacella', referenced by netCDF variable 'clt'
#   warnings.warn(

# %%
###############
# plot ICON
###############
datain = iris.load_cube('/work/bb1153/b381639/model/data_icon/sfcwind_2d_ml_ocean_mean.nc')

datain.data=datain.data

#datain.data=datain.data*-1
regyonx=datain[:,0,:,:]

ERA5=regyonx

######################
#plot a map lat vs Lon
########################
########
#(1) get x-axis and y axis
arr=ar.DataArray.from_iris(ERA5) # iris cube to xarray
latm=arr.latitude.data              # latm is x-axis
lonm=arr.longitude.data +180            # lonm is y-axis  

##################
#(2)set color bar and prepare fig size
levels1=np.arange(0,10,.5) # min and max of the field; dont use it if not sure
#levels1=np.arange(-30,0,1.5) # min and max of the field; dont use it if not sure
#cbar='winter'
#levels1=np.arange(-.5,.5,0.05) # min and max of the field; dont use it if not sure
#cbar='ocean'
#cbar='seismic'
cbar='YlGnBu'
arr = np.roll(arr, 720, axis = 2)
plt.figure(figsize=(30,10))

########
#plot the figure
plt.contourf(lonm,latm,arr[0,:,:],levels=levels1,cmap = cbar)
#plt.contourf(lonm,latm,arr[0,:,:],cmap = cbar)
#plt.title('SST- ICON 5N-5S daily from 20/1/2020')

plt.title('surface windspeed ICON',fontsize=30)
cbar=plt.colorbar(orientation='horizontal', pad=0.13)
cbar.ax.tick_params(labelsize = 25)
        

        
plt.xlabel(('longitude'), fontsize=28)
plt.ylabel(('latitude'), fontsize=28)
plt.xticks(fontsize=25)#, rotation=90)
plt.yticks(fontsize=25)#, rotation=90)

#####save figure
plt.savefig('surface_wind_ICON.eps',format='eps',dpi=1000)
# Out:
# /sw/spack-rhel6/miniforge3-4.9.2-3-Linux-x86_64-pwdbqi/lib/python3.8/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:2190: UserWarning: Ignoring netCDF variable 'time' invalid units 'day as %Y%m%d.%f'
#   warnings.warn(msg)
